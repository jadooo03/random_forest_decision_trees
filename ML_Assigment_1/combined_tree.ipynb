# %% [markdown]
# Import Statements

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import random 
from pprint import pprint

# %% [markdown]
# Load and Prepare Data

# %%
def determine_type_of_feature(df):
    feature_types = []
    n_unique_values_threshold = 15

    for column in df.columns:
        unique_values = df[column].unique()
        example_value = unique_values[0]

        if (isinstance(example_value, str)) or (len(unique_values) <= n_unique_values_threshold):
            feature_types.append("Discrete")
        else:
            feature_types.append("Continuous")
    
    return feature_types

# %%
df = pd.read_csv('census-income.data.csv')
global FEATURE_TYPES
FEATURE_TYPES = determine_type_of_feature(df)

# %%
#Checking which all columns have missing values
def missing_values(df):
    c=0
    for i in df.columns:
        x,count_missing = np.unique(df[i].eq('?'),return_counts=True)
        if len(x)==2:
            print(i,"-",FEATURE_TYPES[c],"-",count_missing[1])
        # elif len(x)==1 and x[0] == False:
        #     print(i,"-",FEATURE_TYPES[c],"- 0",)
        c+=1

# %% [markdown]
# Random Splitting Of Data

# %%
def train_test_split(df,test_size):
    #checks whether the test_size is a proportion of the total number of samples
    if isinstance(test_size,float): 
        test_size = round(test_size*len(df))

    #store random samples in the test and training data
    indices = df.index.tolist()
    test_indices = random.sample(population=indices, k = test_size)

    #random data points from sample sent to test and training data
    test_df = df.loc[test_indices]
    train_df = df.drop(test_indices)

    return train_df , test_df

# %% [markdown]
# Data Pure?

# %%
def check_purity(data):
    label_column = data[:,-1]
    unique_classes = np.unique(label_column)

    if len(unique_classes) ==  1:
        return True    
    else:
        return False

# %% [markdown]
# Classify Data

# %%
def classify_data(data): 
    label_column = data[:,-1]
    unique_classes , counts_unique_classes = np.unique(label_column,return_counts = True)

    index = counts_unique_classes.argmax()
    classification = unique_classes[index]
    return classification

# %%
def get_potential_splits(data):
    potential_splits = {}
    rows , n_columns = data.shape

    for column_index in range(n_columns-1):
        values = data[:,column_index]
        unique_values = np.unique(values)
        
        
        potential_splits[column_index] = unique_values
            
    return potential_splits

# %%
# potential_splits = get_potential_splits(train_df.values)

# sns.lmplot(data = train_df, x = "petal_width", y = "petal_length",hue = "label", fit_reg = False,height=6,aspect = 1.5)

# # plt.vlines(x = potential_splits[3], ymin = 1, ymax =7)
# # plt.hlines(y=potential_splits[2],xmin=0,xmax =2.5)

# %% [markdown]
# Split Data

# %%
def split_data(data, split_column,split_value):
    split_column_values = data[:,split_column]

    type_of_feature = FEATURE_TYPES[split_column]
    
    if type_of_feature == "Continuous":
        data_below = data[split_column_values <= split_value]
        data_above = data[split_column_values > split_value]
    
    else:
        data_below = data[split_column_values == split_value]
        data_above = data[split_column_values != split_value]

    return data_below , data_above

# %%
# split_value = 0.8
# plotting_df = pd.DataFrame(data,columns = df.columns)
# sns.lmplot(data = plotting_df, x = "petal_width", y = "petal_length", fit_reg=False)
# plt.vlines(x = split_value,ymin = 1, ymax =7)

# %%
def calculate_entropy(data):
    label_column = data[:,-1]
    rows , counts = np.unique(label_column , return_counts =True)

    probabilities = counts / counts.sum()
    entropy = np.sum(probabilities*-np.log2(probabilities))

    return entropy

# %%
def calculate_overall_entropy(data_below, data_above):
    
    n_data_points = len(data_below) + len(data_above)

    p_data_below = len(data_below) / n_data_points
    p_data_above = len(data_above) / n_data_points

    overall_entropy = (p_data_below*calculate_entropy(data_below) + p_data_above*calculate_entropy(data_above))

    return overall_entropy

# %%
def determine_best_splits(data, potential_splits):

    overall_entropy = 999
    
    for column_index in potential_splits:
        # print(COLUMN_HEADERS[column_index],"-",len(np.unique(data[:, column_index])))
        for value in potential_splits[column_index]:
            
            data_below, data_above = split_data(data,split_column = column_index,split_value = value)
            current_overall_entropy = calculate_overall_entropy(data_below, data_above)
            
            if current_overall_entropy <= overall_entropy:
                overall_entropy = current_overall_entropy
                best_split_column = column_index
                best_split_value = value
    
    return best_split_column, best_split_value

# %% [markdown]
# Determine Whether Column is Discrete or Continuous

# %%
def decision_tree_algorithm(df , counter =0, min_samples=5, max_depth = 5):
    # print(counter)
    #Data Preparation
    if counter == 0:
        global COLUMN_HEADERS 
        global FEATURE_TYPES 
        COLUMN_HEADERS = df.columns
        FEATURE_TYPES = determine_type_of_feature(df)
        data = df.values
    else:
        data = df

    #Base Case 
    if (check_purity(data)) or (len(data) < min_samples) or (counter == max_depth):
        classification = classify_data(data)
        return classification 
    
    #Recursive case
    else:
        counter = counter + 1
        
        #helper functions
        potential_splits = get_potential_splits(data)        
        split_column,split_value = determine_best_splits(data,potential_splits)
        data_below,data_above = split_data(data,split_column,split_value)

        #checking for empty data

        if len(data_below) == 0 or len(data_above) == 0:
            classification = classify_data(data)
            return classification

        #instantiating the sub-trees
        feature_name = COLUMN_HEADERS[split_column]
        type_of_feature = FEATURE_TYPES[split_column]
        if type_of_feature == "Continuous":
            question = "{} <= {}".format(feature_name,split_value)

        else:
            question = "{} = {}".format(feature_name,split_value)

        sub_tree = {question:[]}

        #find answers (here recursion is used)
        yes_answer = decision_tree_algorithm(data_below, counter, min_samples , max_depth)
        no_answer = decision_tree_algorithm(data_above, counter, min_samples , max_depth)

        if yes_answer == no_answer:
            sub_tree = yes_answer
        else:
            sub_tree[question].append(yes_answer)
            sub_tree[question].append(no_answer)

        return sub_tree

# %%
def classify_example(example,tree):
    question = list(tree.keys())[0]
    feature_name , comparison_operator, value = question.split()

    #Asking the question to the example
    if comparison_operator == "<=":

        if example[feature_name] <= float(value):
            answer = tree[question][0]
        else:
            answer = tree[question][1]

    else:
        if str(example[feature_name]) == value:
            answer = tree[question][0]
        else:
            answer = tree[question][1]
    #base Case
    if not isinstance(answer,dict):
        return answer

    #recursive part
    else:
        remaining_tree = answer
        return classify_example(example,remaining_tree)

# %%
def calculate_accuracy(df,tree):

    df["Classification"] = df.apply(classify_example,axis=1,args = (tree,))
    df["Classification_Correct"] = df.Classification == df.label

    accuracy = df.Classification_Correct.mean()

    return accuracy

# %%
def make_predictions(df, tree):
    
    if len(df) != 0:
        predictions = df.apply(classify_example, args=(tree,), axis=1)
    else:
        # "df.apply()"" with empty dataframe returns an empty dataframe,
        # but "predictions" should be a series instead
        predictions = pd.Series()
        
    return predictions

# %%
def filter_df(df,question):
    feature,comparison_operator,value = question.split()

    if (comparison_operator) == "<=":
        df_yes = df[df[feature]<= float(value)]
        df_no = df[df[feature] > float(value)]
    
    else:
        df_yes = df[df[feature].astype(str) == value]
        df_no = df[df[feature].astype(str) != value]
        

    return df_yes,df_no

# %%
def pruning_result(tree, df_train, df_val):
    leaf = df_train.label.value_counts().index[0]
    errors_leaf = sum(df_val.label != leaf) #here we can find the accuracy also :D
    errors_decision_node = sum(df_val.label != make_predictions(df_val,tree))

    if errors_leaf <= errors_decision_node:
            return leaf
    else:
            return tree

# %%
def post_pruning(tree , df_train , df_val):
    question = list(tree.keys())[0]
    yes_answer , no_answer = tree[question]

    #base case
    if not isinstance(yes_answer,dict) and not isinstance(no_answer,dict):
        return pruning_result(tree , df_train , df_val)
    
    else: #Recursive case
        df_train_yes, df_train_no = filter_df(df_train , question)
        df_val_yes, df_val_no = filter_df(df_val , question)

        if isinstance(yes_answer,dict):
            yes_answer = post_pruning(yes_answer,df_train_yes,df_val_yes)

        if isinstance(no_answer,dict):
            no_answer = post_pruning(no_answer,df_train_no,df_val_no)
    
    tree = {question : [yes_answer,no_answer]}

    return pruning_result(tree , df_train , df_val)

# %%
def count_nodes(tree):
    if isinstance(tree, dict):
        count = 1  # Start with 1 for the current node
        for value in tree.values():
            count += count_nodes(value)  # Recursively count nodes in child dictionaries
        return count
    elif isinstance(tree, list):
        count = 0
        for node in tree:
            count += count_nodes(node)  # Recursively count nodes in child dictionaries
        return count
    else:
        return 1  # Reached a leaf node

# %%
def count_depth(tree):
    if isinstance(tree, dict):
        if not tree:  # Base case: empty dictionary
            return 1
        else:
            return 1 + max(count_depth(value) for value in tree.values())
    elif isinstance(tree, list):
        if not tree:  # Base case: empty list
            return 1
        else:
            return 1 + max(count_depth(item) for item in tree)
    else:
        return 0  # Base case: leaf node or invalid input

# %%
df1 = pd.read_csv("census-income.data.csv")
df2 = pd.read_csv("census-income.test.csv")

# %%
df2['label'] = df2['label'].str.replace('.', '')

# %%
missing_values(df1)
# Out:
# workclass - Discrete - 1836
# occupation - Discrete - 1843
# native_countr - Discrete - 583

# %%
def fill_values(df):
    #Since all columns are having the discrete value. We replace it with the missing values with the modes, i.e. the highest appearing value
    mode_workclass = df.workclass.mode()[0]
    mode_occupation = df.occupation.mode()[0]
    mode_native_countr = df.native_countr.mode()[0]

    #Filling the train and test data with the modes of missing values as they are discrete
    df.workclass = df.workclass.replace('?', mode_workclass)
    df.occupation = df.occupation.replace('?', mode_occupation)
    df.native_countr = df.native_countr.replace('?', mode_native_countr)
    missing_values(df)#No missing values
    return df

# %%
df1 = fill_values(df1)
df2 = fill_values(df2)

# %%
df_combined = pd.concat([df1,df2],ignore_index=True)

# %%
missing_values(df_combined)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education_num   48842 non-null  int64
#  5   marital_status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital_gain    48842 non-null  int64
#  11  capital_loss    48842 non-null  int64
#  12  hours_per_week  48842 non-null  int64
#  13  native_countr   48842 non-null  object
#  14  label           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df_train , df_test = train_test_split(df_combined , 0.33 )

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32724 entries, 2 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32724 non-null  int64
#  1   workclass       32724 non-null  object
#  2   fnlwgt          32724 non-null  int64
#  3   education       32724 non-null  object
#  4   education_num   32724 non-null  int64
#  5   marital_status  32724 non-null  object
#  6   occupation      32724 non-null  object
#  7   relationship    32724 non-null  object
#  8   race            32724 non-null  object
#  9   sex             32724 non-null  object
#  10  capital_gain    32724 non-null  int64
#  11  capital_loss    32724 non-null  int64
#  12  hours_per_week  32724 non-null  int64
#  13  native_countr   32724 non-null  object
#  14  label           32724 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16118 entries, 19002 to 45360
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             16118 non-null  int64
#  1   workclass       16118 non-null  object
#  2   fnlwgt          16118 non-null  int64
#  3   education       16118 non-null  object
#  4   education_num   16118 non-null  int64
#  5   marital_status  16118 non-null  object
#  6   occupation      16118 non-null  object
#  7   relationship    16118 non-null  object
#  8   race            16118 non-null  object
#  9   sex             16118 non-null  object
#  10  capital_gain    16118 non-null  int64
#  11  capital_loss    16118 non-null  int64
#  12  hours_per_week  16118 non-null  int64
#  13  native_countr   16118 non-null  object
#  14  label           16118 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.0+ MB

# %%
tree_combined = decision_tree_algorithm(df_train,max_depth = 40)

# %%
tree = tree_combined

# %%
tree
# Out:
# {'marital_status = Married-civ-spouse': [{'education_num <= 11': [{'capital_gain <= 5013': [{'education_num <= 8': [{'hours_per_week <= 40': [{'education_num <= 5': [{'hours_per_week <= 24': ['<=50K',
#               {'native_countr = Yugoslavia': ['>50K',
#                 {'workclass = Self-emp-inc': [{'native_countr = Mexico': ['>50K',
#                     {'occupation = Machine-op-inspct': ['>50K', '<=50K']}]},
#                   {'occupation = Handlers-cleaners': ['<=50K',
#                     {'occupation = Prof-specialty': ['<=50K',
#                       {'relationship = Wife': [{'education = 5th-6th': [{'fnlwgt <= 175847': [{'hours_per_week <= 35': ['<=50K',
#                               '>50K']},
#                             '<=50K']},
#                           '<=50K']},
#                         {'fnlwgt <= 144594': [{'occupation = Machine-op-inspct': [{'age <= 39': [{'fnlwgt <= 90273': ['>50K',
#                                 '<=50K']},
#                               '<=50K']},
#                             '<=50K']},
#                           {'occupation = Exec-managerial': ['<=50K',
#                             {'fnlwgt <= 155106': [{'workclass = Private': [{'occupation = Sales': ['>50K',
#                                   '<=50K']},
#                                 '>50K']},
#                               {'capital_loss <= 1672': [{'fnlwgt <= 425127': [{'fnlwgt <= 274451': [{'fnlwgt <= 273454': [{'fnlwgt <= 188644': ['<=50K',
#                                         {'fnlwgt <= 189680': ['>50K',
#                                           {'fnlwgt <= 233130': ['<=50K',
#                                             {'fnlwgt <= 237321': [{'age <= 42': ['>50K',
#                                                 '<=50K']},
#                                               {'age <= 56': ['<=50K',
#                                                 {'occupation = Craft-repair': ['>50K',
#                                                   '<=50K']}]}]}]}]}]},
#                                       '>50K']},
#                                     '<=50K']},
#                                   {'fnlwgt <= 425502': ['>50K',
#                                     {'age <= 47': ['<=50K',
#                                       {'education_num <= 4': ['>50K',
#                                         '<=50K']}]}]}]},
#                                 {'capital_loss <= 1902': ['>50K',
#                                   '<=50K']}]}]}]}]}]}]}]}]}]}]},
#             {'age <= 37': [{'occupation = Tech-support': ['>50K',
#                 {'fnlwgt <= 180871': [{'fnlwgt <= 179488': [{'fnlwgt <= 116934': ['<=50K',
#                       {'occupation = Transport-moving': ['<=50K',
#                         {'occupation = Craft-repair': [{'fnlwgt <= 159888': ['<=50K',
#                             '>50K']},
#                           '<=50K']}]}]},
#                     '>50K']},
#                   '<=50K']}]},
#               {'capital_loss <= 1740': [{'age <= 66': [{'age <= 38': [{'education = 11th': ['<=50K',
#                       {'occupation = Other-service': ['<=50K', '>50K']}]},
#                     {'age <= 39': ['<=50K',
#                       {'native_countr = Japan': ['>50K',
#                         {'native_countr = United-States': [{'capital_gain <= 3942': [{'occupation = Farming-fishing': ['<=50K',
#                               {'occupation = Transport-moving': [{'education_num <= 6': [{'age <= 53': [{'fnlwgt <= 101119': ['<=50K',
#                                       {'age <= 43': ['<=50K', '>50K']}]},
#                                     {'fnlwgt <= 245196': [{'capital_loss <= 0': [{'race = White': [{'fnlwgt <= 65325': ['>50K',
#                                             {'age <= 63': ['<=50K', '>50K']}]},
#                                           '>50K']},
#                                         '>50K']},
#                                       '<=50K']}]},
#                                   {'workclass = Self-emp-inc': ['>50K',
#                                     {'age <= 48': [{'age <= 46': ['<=50K',
#                                         '>50K']},
#                                       '<=50K']}]}]},
#                                 {'education_num <= 7': [{'age <= 63': [{'occupation = Handlers-cleaners': ['<=50K',
#                                       {'fnlwgt <= 53366': ['<=50K',
#                                         {'fnlwgt <= 72442': ['>50K',
#                                           {'occupation = Prof-specialty': ['<=50K',
#                                             {'age <= 60': [{'occupation = Exec-managerial': [{'fnlwgt <= 158555': ['<=50K',
#                                                   '>50K']},
#                                                 {'age <= 41': ['<=50K',
#                                                   {'workclass = Self-emp-not-inc': ['<=50K',
#                                                     {'fnlwgt <= 187510': [{'fnlwgt <= 120914': ['<=50K',
#                                                         {'occupation = Sales': ['>50K',
#                                                           {'sex = Male': [{'fnlwgt <= 186385': [{'occupation = Craft-repair': [{'fnlwgt <= 165050': [{'fnlwgt <= 151325': ['<=50K',
#                                                                     '>50K']},
#                                                                   '<=50K']},
#                                                                 {'age <= 47': [{'fnlwgt <= 166863': ['<=50K',
#                                                                     '>50K']},
#                                                                   '<=50K']}]},
#                                                               '>50K']},
#                                                             '>50K']}]}]},
#                                                       {'occupation = Machine-op-inspct': ['<=50K',
#                                                         {'fnlwgt <= 368005': [{'occupation = Other-service': ['<=50K',
#                                                             {'age <= 44': ['>50K',
#                                                               {'fnlwgt <= 211654': [{'fnlwgt <= 203039': ['<=50K',
#                                                                   '>50K']},
#                                                                 '<=50K']}]}]},
#                                                           '>50K']}]}]}]}]}]},
#                                               '<=50K']}]}]}]}]},
#                                     {'hours_per_week <= 15': ['>50K',
#                                       {'fnlwgt <= 36209': ['>50K',
#                                         '<=50K']}]}]},
#                                   {'workclass = Self-emp-not-inc': ['>50K',
#                                     {'fnlwgt <= 34377': ['>50K',
#                                       {'age <= 59': [{'occupation = Prof-specialty': ['>50K',
#                                           {'age <= 58': [{'age <= 45': [{'fnlwgt <= 257758': [{'fnlwgt <= 82319': ['<=50K',
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               '<=50K']},
#                                             '>50K']}]},
#                                         '<=50K']}]}]}]}]}]},
#                             '>50K']},
#                           '<=50K']}]}]}]},
#                   '<=50K']},
#                 {'capital_loss <= 1902': ['>50K', '<=50K']}]}]}]},
#           {'occupation = Exec-managerial': [{'age <= 56': [{'fnlwgt <= 101722': [{'capital_loss <= 0': ['<=50K',
#                   '>50K']},
#                 {'native_countr = United-States': [{'fnlwgt <= 242184': [{'fnlwgt <= 194259': [{'fnlwgt <= 192053': [{'education_num <= 5': ['>50K',
#                           {'fnlwgt <= 141511': ['>50K', '<=50K']}]},
#                         '<=50K']},
#                       '>50K']},
#                     '<=50K']},
#                   '<=50K']}]},
#               {'native_countr = Ireland': ['<=50K', '>50K']}]},
#             {'occupation = Other-service': ['<=50K',
#               {'age <= 27': [{'education = 11th': [{'fnlwgt <= 212888': ['<=50K',
#                     {'fnlwgt <= 235071': ['>50K', '<=50K']}]},
#                   '<=50K']},
#                 {'age <= 64': [{'relationship = Own-child': ['>50K',
#                     {'age <= 46': [{'native_countr = Portugal': [{'education = 7th-8th': ['<=50K',
#                           '>50K']},
#                         {'native_countr = Canada': ['>50K',
#                           {'occupation = Craft-repair': [{'age <= 42': [{'age <= 39': [{'age <= 34': [{'fnlwgt <= 244268': [{'fnlwgt <= 87943': ['<=50K',
#                                       {'age <= 32': [{'workclass = Private': ['<=50K',
#                                           '>50K']},
#                                         '>50K']}]},
#                                     '>50K']},
#                                   '<=50K']},
#                                 {'education = 10th': ['<=50K', '>50K']}]},
#                               '<=50K']},
#                             {'occupation = Protective-serv': ['>50K',
#                               {'hours_per_week <= 75': [{'occupation = Farming-fishing': ['<=50K',
#                                   {'age <= 45': [{'age <= 37': [{'age <= 36': [{'occupation = Transport-moving': [{'education_num <= 3': ['>50K',
#                                             {'age <= 32': [{'hours_per_week <= 45': ['>50K',
#                                                 '<=50K']},
#                                               '<=50K']}]},
#                                           '<=50K']},
#                                         {'fnlwgt <= 186934': [{'hours_per_week <= 55': [{'occupation = Transport-moving': ['<=50K',
#                                               '>50K']},
#                                             '>50K']},
#                                           '<=50K']}]},
#                                       '<=50K']},
#                                     '<=50K']}]},
#                                 {'age <= 32': ['>50K',
#                                   {'education = 5th-6th': ['>50K',
#                                     '<=50K']}]}]}]}]}]}]},
#                       {'hours_per_week <= 53': [{'fnlwgt <= 31782': ['>50K',
#                           {'hours_per_week <= 44': [{'age <= 53': ['>50K',
#                               '<=50K']},
#                             {'education_num <= 3': ['<=50K',
#                               {'fnlwgt <= 80026': ['<=50K',
#                                 {'fnlwgt <= 84231': ['>50K',
#                                   {'fnlwgt <= 111553': ['<=50K',
#                                     {'age <= 53': [{'fnlwgt <= 127149': ['>50K',
#                                         {'age <= 48': ['>50K',
#                                           {'fnlwgt <= 199688': ['<=50K',
#                                             {'fnlwgt <= 232132': ['>50K',
#                                               '<=50K']}]}]}]},
#                                       {'age <= 57': ['<=50K',
#                                         {'fnlwgt <= 407138': [{'age <= 59': ['<=50K',
#                                             {'native_countr = Mexico': ['>50K',
#                                               '<=50K']}]},
#                                           '>50K']}]}]}]}]}]}]}]}]},
#                         {'hours_per_week <= 72': [{'age <= 56': [{'fnlwgt <= 177995': [{'occupation = Farming-fishing': [{'education_num <= 6': ['>50K',
#                                   '<=50K']},
#                                 {'native_countr = United-States': [{'education_num <= 6': ['<=50K',
#                                     '>50K']},
#                                   '>50K']}]},
#                               {'occupation = Craft-repair': ['>50K',
#                                 '<=50K']}]},
#                             {'education = 9th': ['>50K',
#                               {'fnlwgt <= 135647': ['<=50K',
#                                 {'native_countr = United-States': [{'race = White': ['>50K',
#                                     '<=50K']},
#                                   '<=50K']}]}]}]},
#                           {'capital_gain <= 0': ['<=50K', '>50K']}]}]}]}]},
#                   '<=50K']}]}]}]}]},
#         {'capital_loss <= 1844': [{'age <= 33': [{'age <= 24': [{'occupation = Transport-moving': [{'fnlwgt <= 313817': [{'education_num <= 9': ['<=50K',
#                     {'hours_per_week <= 65': [{'hours_per_week <= 60': [{'hours_per_week <= 24': ['<=50K',
#                           {'fnlwgt <= 38707': ['>50K', '<=50K']}]},
#                         '<=50K']},
#                       '>50K']}]},
#                   '>50K']},
#                 {'fnlwgt <= 194654': [{'fnlwgt <= 52242': [{'hours_per_week <= 50': [{'fnlwgt <= 50400': ['<=50K',
#                         '>50K']},
#                       '>50K']},
#                     '<=50K']},
#                   {'fnlwgt <= 196943': ['>50K',
#                     {'hours_per_week <= 68': [{'fnlwgt <= 456367': [{'fnlwgt <= 325179': [{'fnlwgt <= 318987': [{'native_countr = Mexico': ['<=50K',
#                               {'education = Some-college': [{'fnlwgt <= 229826': ['<=50K',
#                                   {'fnlwgt <= 249727': ['>50K', '<=50K']}]},
#                                 '<=50K']}]},
#                             '>50K']},
#                           '<=50K']},
#                         {'occupation = Prof-specialty': ['>50K',
#                           {'fnlwgt <= 461678': ['>50K', '<=50K']}]}]},
#                       '>50K']}]}]}]},
#               {'education_num <= 9': [{'hours_per_week <= 37': [{'fnlwgt <= 159662': [{'occupation = Prof-specialty': [{'hours_per_week <= 10': ['>50K',
#                         '<=50K']},
#                       {'fnlwgt <= 156848': ['<=50K', '>50K']}]},
#                     '<=50K']},
#                   {'occupation = Exec-managerial': [{'fnlwgt <= 114072': [{'workclass = Self-emp-not-inc': ['<=50K',
#                         {'fnlwgt <= 39054': ['>50K',
#                           {'fnlwgt <= 49923': ['<=50K',
#                             {'hours_per_week <= 65': [{'capital_loss <= 0': [{'age <= 31': [{'hours_per_week <= 50': [{'fnlwgt <= 103435': ['<=50K',
#                                       '>50K']},
#                                     '>50K']},
#                                   '>50K']},
#                                 '<=50K']},
#                               '<=50K']}]}]}]},
#                       {'hours_per_week <= 75': [{'age <= 30': [{'hours_per_week <= 45': ['<=50K',
#                             {'age <= 25': ['>50K', '<=50K']}]},
#                           {'age <= 31': [{'hours_per_week <= 50': ['>50K',
#                               '<=50K']},
#                             {'native_countr = Mexico': ['>50K', '<=50K']}]}]},
#                         '>50K']}]},
#                     {'occupation = Protective-serv': [{'age <= 31': [{'fnlwgt <= 326104': [{'workclass = State-gov': [{'age <= 29': ['<=50K',
#                               '>50K']},
#                             {'fnlwgt <= 199172': [{'race = White': ['<=50K',
#                                 '>50K']},
#                               '>50K']}]},
#                           '<=50K']},
#                         '<=50K']},
#                       {'race = Black': ['<=50K',
#                         {'native_countr = Ireland': ['>50K',
#                           {'occupation = Tech-support': [{'hours_per_week <= 40': [{'workclass = Private': [{'age <= 27': ['<=50K',
#                                   {'fnlwgt <= 108706': ['>50K',
#                                     {'fnlwgt <= 111567': ['<=50K',
#                                       '>50K']}]}]},
#                                 '<=50K']},
#                               {'hours_per_week <= 75': ['>50K', '<=50K']}]},
#                             {'occupation = Sales': [{'age <= 26': ['<=50K',
#                                 {'age <= 30': [{'age <= 29': [{'fnlwgt <= 190836': [{'fnlwgt <= 189407': [{'hours_per_week <= 55': [{'capital_gain <= 0': ['<=50K',
#                                             '>50K']},
#                                           '>50K']},
#                                         '>50K']},
#                                       '<=50K']},
#                                     '<=50K']},
#                                   {'native_countr = United-States': [{'capital_gain <= 0': [{'fnlwgt <= 56150': ['<=50K',
#                                         {'fnlwgt <= 110331': ['>50K',
#                                           {'age <= 32': [{'sex = Male': [{'fnlwgt <= 194901': [{'hours_per_week <= 50': [{'workclass = Private': [{'fnlwgt <= 136921': ['<=50K',
#                                                       '>50K']},
#                                                     '<=50K']},
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               '>50K']},
#                                             {'fnlwgt <= 303867': [{'fnlwgt <= 131568': ['<=50K',
#                                                 '>50K']},
#                                               '<=50K']}]}]}]},
#                                       '<=50K']},
#                                     '<=50K']}]}]},
#                               {'workclass = Self-emp-not-inc': [{'fnlwgt <= 33363': ['<=50K',
#                                   {'fnlwgt <= 203408': ['<=50K',
#                                     {'fnlwgt <= 204052': ['>50K',
#                                       '<=50K']}]}]},
#                                 {'fnlwgt <= 271276': [{'capital_gain <= 3942': [{'fnlwgt <= 103596': [{'occupation = Transport-moving': [{'age <= 27': ['>50K',
#                                           '<=50K']},
#                                         {'native_countr = Vietnam': ['>50K',
#                                           {'fnlwgt <= 50178': [{'occupation = Adm-clerical': ['<=50K',
#                                               {'fnlwgt <= 49325': ['<=50K',
#                                                 '>50K']}]},
#                                             '<=50K']}]}]},
#                                       {'occupation = Prof-specialty': [{'native_countr = United-States': [{'age <= 31': ['>50K',
#                                             '<=50K']},
#                                           '<=50K']},
#                                         {'race = White': [{'age <= 29': [{'hours_per_week <= 52': [{'hours_per_week <= 50': [{'workclass = State-gov': ['>50K',
#                                                   {'fnlwgt <= 116662': ['<=50K',
#                                                     {'fnlwgt <= 135603': [{'occupation = Transport-moving': ['>50K',
#                                                         {'fnlwgt <= 134890': [{'sex = Male': [{'age <= 28': [{'fnlwgt <= 129806': ['<=50K',
#                                                                 '>50K']},
#                                                               '<=50K']},
#                                                             '>50K']},
#                                                           '<=50K']}]},
#                                                       {'age <= 26': [{'occupation = Handlers-cleaners': ['<=50K',
#                                                           {'occupation = Transport-moving': ['<=50K',
#                                                             {'hours_per_week <= 42': [{'fnlwgt <= 230292': [{'occupation = Craft-repair': [{'fnlwgt <= 210521': [{'fnlwgt <= 189897': ['<=50K',
#                                                                       '>50K']},
#                                                                     '<=50K']},
#                                                                   '<=50K']},
#                                                                 '>50K']},
#                                                               {'sex = Male': ['<=50K',
#                                                                 '>50K']}]}]}]},
#                                                         {'age <= 28': [{'fnlwgt <= 263728': [{'fnlwgt <= 173944': [{'fnlwgt <= 172891': ['<=50K',
#                                                                 '>50K']},
#                                                               '<=50K']},
#                                                             '<=50K']},
#                                                           {'native_countr = Mexico': ['>50K',
#                                                             {'fnlwgt <= 229124': [{'fnlwgt <= 217200': [{'fnlwgt <= 204984': [{'fnlwgt <= 201101': [{'fnlwgt <= 177413': [{'fnlwgt <= 173851': ['<=50K',
#                                                                         '>50K']},
#                                                                       '<=50K']},
#                                                                     '>50K']},
#                                                                   '<=50K']},
#                                                                 '>50K']},
#                                                               '<=50K']}]}]}]}]}]}]},
#                                                 '>50K']},
#                                               '<=50K']},
#                                             {'hours_per_week <= 77': [{'fnlwgt <= 103651': ['>50K',
#                                                 {'fnlwgt <= 204577': [{'occupation = Other-service': ['<=50K',
#                                                     {'capital_gain <= 0': [{'fnlwgt <= 196266': [{'fnlwgt <= 195000': [{'workclass = Private': [{'hours_per_week <= 50': [{'fnlwgt <= 136651': [{'fnlwgt <= 114691': [{'fnlwgt <= 108256': ['<=50K',
#                                                                     {'hours_per_week <= 40': ['>50K',
#                                                                       '<=50K']}]},
#                                                                   '<=50K']},
#                                                                 {'fnlwgt <= 140206': ['>50K',
#                                                                   {'occupation = Handlers-cleaners': [{'fnlwgt <= 161599': ['>50K',
#                                                                       '<=50K']},
#                                                                     {'fnlwgt <= 170017': [{'fnlwgt <= 158291': [{'fnlwgt <= 152156': ['<=50K',
#                                                                           {'occupation = Craft-repair': ['>50K',
#                                                                             '<=50K']}]},
#                                                                         '<=50K']},
#                                                                       {'fnlwgt <= 190511': [{'age <= 31': [{'hours_per_week <= 38': ['<=50K',
#                                                                             {'fnlwgt <= 173005': ['<=50K',
#                                                                               {'fnlwgt <= 180551': ['>50K',
#                                                                                 '<=50K']}]}]},
#                                                                           {'fnlwgt <= 171091': ['>50K',
#                                                                             '<=50K']}]},
#                                                                         '<=50K']}]}]}]}]},
#                                                               '<=50K']},
#                                                             {'age <= 32': [{'fnlwgt <= 127651': ['>50K',
#                                                                 {'fnlwgt <= 157990': ['<=50K',
#                                                                   '>50K']}]},
#                                                               '<=50K']}]},
#                                                           '>50K']},
#                                                         '<=50K']},
#                                                       '<=50K']}]},
#                                                   {'workclass = Federal-gov': ['>50K',
#                                                     {'fnlwgt <= 207201': ['>50K',
#                                                       {'hours_per_week <= 50': [{'fnlwgt <= 259425': [{'fnlwgt <= 255004': [{'occupation = Adm-clerical': ['<=50K',
#                                                               {'fnlwgt <= 250804': [{'fnlwgt <= 250782': [{'fnlwgt <= 232475': [{'fnlwgt <= 229636': [{'fnlwgt <= 226443': [{'age <= 32': [{'fnlwgt <= 207668': ['<=50K',
#                                                                             {'hours_per_week <= 45': [{'fnlwgt <= 215297': ['<=50K',
#                                                                                 '>50K']},
#                                                                               '>50K']}]},
#                                                                           '<=50K']},
#                                                                         '<=50K']},
#                                                                       '>50K']},
#                                                                     '<=50K']},
#                                                                   '>50K']},
#                                                                 '<=50K']}]},
#                                                             '>50K']},
#                                                           '<=50K']},
#                                                         '<=50K']}]}]}]}]},
#                                               '>50K']}]},
#                                           '<=50K']}]}]},
#                                     {'capital_gain <= 4386': ['>50K',
#                                       '<=50K']}]},
#                                   {'hours_per_week <= 40': [{'fnlwgt <= 402361': ['<=50K',
#                                       {'fnlwgt <= 405765': ['>50K',
#                                         {'fnlwgt <= 460408': [{'fnlwgt <= 459465': ['<=50K',
#                                             '>50K']},
#                                           '<=50K']}]}]},
#                                     {'fnlwgt <= 295282': ['<=50K',
#                                       {'fnlwgt <= 306420': [{'age <= 31': ['<=50K',
#                                           '>50K']},
#                                         '<=50K']}]}]}]}]}]}]}]}]}]}]}]},
#                 {'workclass = Federal-gov': [{'age <= 26': ['<=50K',
#                     {'age <= 29': ['>50K',
#                       {'age <= 31': [{'occupation = Armed-Forces': ['>50K',
#                           '<=50K']},
#                         '>50K']}]}]},
#                   {'fnlwgt <= 152351': [{'relationship = Husband': [{'hours_per_week <= 36': ['<=50K',
#                         {'age <= 31': [{'native_countr = Philippines': ['>50K',
#                             {'native_countr = Iran': ['>50K',
#                               {'workclass = Local-gov': [{'fnlwgt <= 98590': ['>50K',
#                                   '<=50K']},
#                                 {'fnlwgt <= 132601': [{'fnlwgt <= 113543': [{'fnlwgt <= 113364': [{'workclass = Private': [{'age <= 29': [{'occupation = Exec-managerial': [{'hours_per_week <= 40': ['>50K',
#                                               '<=50K']},
#                                             '<=50K']},
#                                           {'occupation = Transport-moving': ['>50K',
#                                             {'hours_per_week <= 38': ['>50K',
#                                               {'age <= 30': [{'fnlwgt <= 89735': [{'occupation = Prof-specialty': ['>50K',
#                                                     {'fnlwgt <= 30101': ['>50K',
#                                                       '<=50K']}]},
#                                                   '<=50K']},
#                                                 '<=50K']}]}]}]},
#                                         '<=50K']},
#                                       '>50K']},
#                                     '<=50K']},
#                                   {'fnlwgt <= 134890': [{'occupation = Craft-repair': ['<=50K',
#                                       '>50K']},
#                                     {'fnlwgt <= 147951': ['<=50K',
#                                       {'capital_loss <= 0': ['<=50K',
#                                         '>50K']}]}]}]}]}]}]},
#                           {'hours_per_week <= 45': [{'fnlwgt <= 119913': [{'fnlwgt <= 112820': [{'workclass = Private': [{'capital_gain <= 0': ['<=50K',
#                                     '>50K']},
#                                   '>50K']},
#                                 '>50K']},
#                               '<=50K']},
#                             {'fnlwgt <= 113838': [{'occupation = Exec-managerial': ['>50K',
#                                 {'fnlwgt <= 33678': [{'occupation = Craft-repair': ['<=50K',
#                                     '>50K']},
#                                   '<=50K']}]},
#                               {'hours_per_week <= 55': ['>50K',
#                                 '<=50K']}]}]}]}]},
#                       {'occupation = Other-service': ['<=50K',
#                         {'age <= 31': [{'age <= 25': ['>50K',
#                             {'occupation = Prof-specialty': [{'hours_per_week <= 36': ['>50K',
#                                 {'race = White': ['<=50K', '>50K']}]},
#                               {'fnlwgt <= 146343': ['<=50K', '>50K']}]}]},
#                           '>50K']}]}]},
#                     {'capital_gain <= 3103': [{'capital_gain <= 2885': [{'age <= 29': [{'hours_per_week <= 25': ['<=50K',
#                             {'relationship = Wife': [{'fnlwgt <= 157950': ['>50K',
#                                 {'fnlwgt <= 167336': ['<=50K',
#                                   {'occupation = Prof-specialty': ['>50K',
#                                     {'fnlwgt <= 218785': ['<=50K',
#                                       {'fnlwgt <= 263773': ['>50K',
#                                         {'race = White': ['<=50K',
#                                           '>50K']}]}]}]}]}]},
#                               {'race = Black': ['<=50K',
#                                 {'fnlwgt <= 330695': [{'fnlwgt <= 250038': [{'occupation = Machine-op-inspct': ['<=50K',
#                                       {'fnlwgt <= 190628': [{'fnlwgt <= 183523': [{'fnlwgt <= 182308': [{'hours_per_week <= 40': ['<=50K',
#                                               {'occupation = Tech-support': ['>50K',
#                                                 {'fnlwgt <= 155057': ['>50K',
#                                                   '<=50K']}]}]},
#                                             '>50K']},
#                                           '<=50K']},
#                                         {'fnlwgt <= 193165': ['>50K',
#                                           {'fnlwgt <= 249720': [{'occupation = Prof-specialty': [{'education_num <= 10': ['<=50K',
#                                                 '>50K']},
#                                               {'hours_per_week <= 50': [{'fnlwgt <= 207473': [{'hours_per_week <= 35': ['>50K',
#                                                     '<=50K']},
#                                                   {'hours_per_week <= 40': [{'fnlwgt <= 223751': [{'occupation = Sales': ['>50K',
#                                                         {'fnlwgt <= 223464': [{'age <= 26': [{'age <= 25': ['<=50K',
#                                                               {'occupation = Craft-repair': ['>50K',
#                                                                 '<=50K']}]},
#                                                             '<=50K']},
#                                                           '>50K']}]},
#                                                       '<=50K']},
#                                                     '>50K']}]},
#                                                 '<=50K']}]},
#                                             '>50K']}]}]}]},
#                                     '<=50K']},
#                                   {'fnlwgt <= 391867': [{'fnlwgt <= 370242': [{'occupation = Exec-managerial': ['<=50K',
#                                         {'capital_gain <= 0': [{'occupation = Craft-repair': ['<=50K',
#                                             '>50K']},
#                                           '<=50K']}]},
#                                       '>50K']},
#                                     {'age <= 27': ['<=50K',
#                                       {'age <= 28': [{'native_countr = United-States': ['>50K',
#                                           '<=50K']},
#                                         '<=50K']}]}]}]}]}]}]},
#                           {'occupation = Exec-managerial': [{'hours_per_week <= 35': ['>50K',
#                               {'relationship = Husband': [{'fnlwgt <= 158438': ['>50K',
#                                   {'fnlwgt <= 180303': ['<=50K',
#                                     {'fnlwgt <= 205469': ['>50K',
#                                       {'fnlwgt <= 261943': ['<=50K',
#                                         {'native_countr = Germany': ['<=50K',
#                                           {'fnlwgt <= 345489': [{'fnlwgt <= 303867': ['<=50K',
#                                               '>50K']},
#                                             {'age <= 31': ['>50K',
#                                               '<=50K']}]}]}]}]}]}]},
#                                 '<=50K']}]},
#                             {'native_countr = United-States': [{'hours_per_week <= 18': ['<=50K',
#                                 {'hours_per_week <= 75': [{'hours_per_week <= 24': ['>50K',
#                                     {'hours_per_week <= 60': [{'hours_per_week <= 52': [{'occupation = Other-service': ['<=50K',
#                                           {'capital_loss <= 0': [{'occupation = Adm-clerical': [{'fnlwgt <= 286911': [{'fnlwgt <= 159123': ['>50K',
#                                                   '<=50K']},
#                                                 '>50K']},
#                                               {'fnlwgt <= 264554': [{'fnlwgt <= 259301': [{'fnlwgt <= 236379': [{'fnlwgt <= 231263': [{'fnlwgt <= 218551': [{'fnlwgt <= 199248': [{'fnlwgt <= 196385': [{'fnlwgt <= 187560': [{'fnlwgt <= 176998': [{'fnlwgt <= 176862': [{'fnlwgt <= 172304': [{'hours_per_week <= 45': [{'occupation = Sales': ['>50K',
#                                                                         {'fnlwgt <= 155914': ['<=50K',
#                                                                           {'fnlwgt <= 156192': ['>50K',
#                                                                             {'occupation = Craft-repair': ['<=50K',
#                                                                               {'hours_per_week <= 25': ['>50K',
#                                                                                 '<=50K']}]}]}]}]},
#                                                                       '>50K']},
#                                                                     '<=50K']},
#                                                                   '>50K']},
#                                                                 '<=50K']},
#                                                               {'age <= 30': ['<=50K',
#                                                                 '>50K']}]},
#                                                             '<=50K']},
#                                                           {'occupation = Machine-op-inspct': ['>50K',
#                                                             {'hours_per_week <= 44': [{'fnlwgt <= 200246': ['>50K',
#                                                                 {'occupation = Tech-support': ['>50K',
#                                                                   '<=50K']}]},
#                                                               '>50K']}]}]},
#                                                         '<=50K']},
#                                                       '>50K']},
#                                                     '<=50K']},
#                                                   '>50K']},
#                                                 {'age <= 32': [{'age <= 31': [{'occupation = Transport-moving': ['>50K',
#                                                       {'workclass = Self-emp-not-inc': ['>50K',
#                                                         '<=50K']}]},
#                                                     '<=50K']},
#                                                   {'fnlwgt <= 283921': ['<=50K',
#                                                     {'fnlwgt <= 511289': [{'fnlwgt <= 317660': ['>50K',
#                                                         {'hours_per_week <= 40': ['<=50K',
#                                                           '>50K']}]},
#                                                       '<=50K']}]}]}]}]},
#                                             '<=50K']}]},
#                                         {'sex = Male': [{'occupation = Sales': ['>50K',
#                                             {'fnlwgt <= 251659': [{'fnlwgt <= 209538': [{'hours_per_week <= 54': ['>50K',
#                                                   '<=50K']},
#                                                 {'occupation = Craft-repair': ['<=50K',
#                                                   '>50K']}]},
#                                               '<=50K']}]},
#                                           '>50K']}]},
#                                       '<=50K']}]},
#                                   '>50K']}]},
#                               {'fnlwgt <= 395170': ['<=50K',
#                                 {'native_countr = Peru': ['>50K',
#                                   {'occupation = Tech-support': ['>50K',
#                                     '<=50K']}]}]}]}]}]},
#                         '>50K']},
#                       '<=50K']}]}]}]}]},
#             {'hours_per_week <= 34': [{'education_num <= 9': [{'relationship = Wife': [{'fnlwgt <= 95577': ['<=50K',
#                     {'age <= 47': [{'age <= 44': [{'fnlwgt <= 178866': [{'fnlwgt <= 112656': ['<=50K',
#                             {'hours_per_week <= 25': [{'native_countr = United-States': ['>50K',
#                                 '<=50K']},
#                               '<=50K']}]},
#                           '<=50K']},
#                         '>50K']},
#                       {'fnlwgt <= 133821': [{'workclass = Self-emp-inc': ['>50K',
#                           '<=50K']},
#                         '<=50K']}]}]},
#                   {'fnlwgt <= 271901': [{'hours_per_week <= 29': [{'age <= 68': [{'hours_per_week <= 1': ['>50K',
#                           {'fnlwgt <= 197148': [{'fnlwgt <= 186943': ['<=50K',
#                               {'workclass = Self-emp-not-inc': ['<=50K',
#                                 {'occupation = Transport-moving': ['<=50K',
#                                   {'fnlwgt <= 188102': ['>50K',
#                                     {'hours_per_week <= 18': ['<=50K',
#                                       '>50K']}]}]}]}]},
#                             '<=50K']}]},
#                         '<=50K']},
#                       {'age <= 44': ['<=50K',
#                         {'age <= 47': ['>50K',
#                           {'occupation = Exec-managerial': [{'native_countr = United-States': ['>50K',
#                               '<=50K']},
#                             {'occupation = Prof-specialty': [{'fnlwgt <= 198727': [{'fnlwgt <= 110122': ['>50K',
#                                   '<=50K']},
#                                 '>50K']},
#                               {'capital_gain <= 3464': ['<=50K',
#                                 '>50K']}]}]}]}]}]},
#                     '<=50K']}]},
#                 {'sex = Male': [{'fnlwgt <= 193260': [{'fnlwgt <= 172637': [{'fnlwgt <= 171482': [{'fnlwgt <= 98979': [{'fnlwgt <= 90290': [{'age <= 46': ['<=50K',
#                               {'age <= 53': ['>50K',
#                                 {'age <= 77': [{'fnlwgt <= 57435': [{'education_num <= 10': [{'fnlwgt <= 31362': ['<=50K',
#                                         '>50K']},
#                                       '<=50K']},
#                                     '<=50K']},
#                                   '>50K']}]}]},
#                             '>50K']},
#                           {'fnlwgt <= 121318': ['<=50K',
#                             {'workclass = Private': [{'occupation = Protective-serv': ['>50K',
#                                 {'fnlwgt <= 121912': ['>50K',
#                                   {'age <= 42': [{'hours_per_week <= 25': ['>50K',
#                                       '<=50K']},
#                                     '<=50K']}]}]},
#                               '<=50K']}]}]},
#                         '>50K']},
#                       '<=50K']},
#                     {'fnlwgt <= 197114': ['>50K',
#                       {'fnlwgt <= 205011': ['<=50K',
#                         {'native_countr = France': ['>50K',
#                           {'occupation = Tech-support': ['>50K',
#                             {'fnlwgt <= 573446': [{'fnlwgt <= 205724': ['>50K',
#                                 {'fnlwgt <= 410980': [{'occupation = Prof-specialty': [{'hours_per_week <= 24': [{'hours_per_week <= 12': ['>50K',
#                                         {'hours_per_week <= 14': ['<=50K',
#                                           {'capital_loss <= 0': ['>50K',
#                                             '<=50K']}]}]},
#                                       '<=50K']},
#                                     {'fnlwgt <= 249585': ['<=50K',
#                                       {'occupation = Craft-repair': ['>50K',
#                                         {'age <= 68': [{'workclass = Self-emp-inc': ['>50K',
#                                             '<=50K']},
#                                           '>50K']}]}]}]},
#                                   '<=50K']}]},
#                               '>50K']}]}]}]}]}]},
#                   {'hours_per_week <= 10': ['<=50K',
#                     {'hours_per_week <= 17': [{'occupation = Adm-clerical': ['>50K',
#                         {'fnlwgt <= 151990': [{'occupation = Other-service': ['<=50K',
#                             '>50K']},
#                           '<=50K']}]},
#                       {'age <= 57': [{'fnlwgt <= 338281': [{'fnlwgt <= 31709': ['>50K',
#                             {'native_countr = Mexico': ['>50K',
#                               {'occupation = Tech-support': ['>50K',
#                                 {'age <= 55': [{'age <= 41': [{'occupation = Prof-specialty': ['>50K',
#                                       {'relationship = Own-child': ['>50K',
#                                         '<=50K']}]},
#                                     '<=50K']},
#                                   '>50K']}]}]}]},
#                           '>50K']},
#                         '<=50K']}]}]}]}]},
#               {'education_num <= 9': [{'occupation = Other-service': [{'workclass = Self-emp-not-inc': ['<=50K',
#                     {'age <= 61': [{'native_countr = Jamaica': ['>50K',
#                         {'hours_per_week <= 38': ['<=50K',
#                           {'native_countr = Germany': ['>50K',
#                             {'hours_per_week <= 78': [{'fnlwgt <= 119986': ['<=50K',
#                                 {'fnlwgt <= 123211': ['>50K',
#                                   {'fnlwgt <= 135289': ['<=50K',
#                                     {'fnlwgt <= 151835': [{'hours_per_week <= 45': [{'fnlwgt <= 142182': ['>50K',
#                                           '<=50K']},
#                                         '>50K']},
#                                       {'fnlwgt <= 189794': [{'fnlwgt <= 169818': [{'fnlwgt <= 169133': ['<=50K',
#                                             '>50K']},
#                                           '<=50K']},
#                                         {'fnlwgt <= 230136': [{'age <= 48': [{'fnlwgt <= 218955': [{'age <= 42': ['<=50K',
#                                                 {'capital_gain <= 0': [{'age <= 43': ['<=50K',
#                                                     '>50K']},
#                                                   '<=50K']}]},
#                                               {'hours_per_week <= 43': ['>50K',
#                                                 '<=50K']}]},
#                                             '<=50K']},
#                                           {'age <= 46': ['<=50K',
#                                             {'age <= 47': ['>50K',
#                                               {'age <= 57': ['<=50K',
#                                                 {'age <= 58': ['>50K',
#                                                   '<=50K']}]}]}]}]}]}]}]}]}]},
#                               '>50K']}]}]}]},
#                       {'fnlwgt <= 146674': [{'workclass = Private': ['<=50K',
#                           '>50K']},
#                         '<=50K']}]}]},
#                   {'occupation = Farming-fishing': [{'hours_per_week <= 43': [{'native_countr = Cambodia': ['>50K',
#                         {'fnlwgt <= 97213': [{'fnlwgt <= 88500': ['<=50K',
#                             '>50K']},
#                           '<=50K']}]},
#                       {'hours_per_week <= 84': [{'fnlwgt <= 20795': ['>50K',
#                           {'fnlwgt <= 34233': ['<=50K',
#                             {'fnlwgt <= 37237': ['>50K',
#                               {'age <= 60': [{'workclass = Self-emp-inc': ['<=50K',
#                                   {'fnlwgt <= 231770': [{'fnlwgt <= 216657': [{'capital_loss <= 0': [{'fnlwgt <= 154641': [{'fnlwgt <= 129150': [{'hours_per_week <= 65': [{'age <= 48': ['<=50K',
#                                                 {'fnlwgt <= 94432': ['>50K',
#                                                   '<=50K']}]},
#                                               '<=50K']},
#                                             '<=50K']},
#                                           {'age <= 51': [{'fnlwgt <= 159869': ['>50K',
#                                               {'fnlwgt <= 168539': ['<=50K',
#                                                 '>50K']}]},
#                                             '<=50K']}]},
#                                         '<=50K']},
#                                       '>50K']},
#                                     '<=50K']}]},
#                                 '<=50K']}]}]}]},
#                         '<=50K']}]},
#                     {'age <= 36': [{'hours_per_week <= 45': [{'fnlwgt <= 24106': ['>50K',
#                           {'fnlwgt <= 67728': ['<=50K',
#                             {'occupation = Machine-op-inspct': [{'fnlwgt <= 209629': ['<=50K',
#                                 {'fnlwgt <= 220696': ['>50K',
#                                   {'fnlwgt <= 264651': [{'fnlwgt <= 260560': ['<=50K',
#                                       '>50K']},
#                                     '<=50K']}]}]},
#                               {'relationship = Wife': [{'hours_per_week <= 35': ['>50K',
#                                   {'age <= 35': [{'occupation = Craft-repair': ['>50K',
#                                       '<=50K']},
#                                     {'fnlwgt <= 128516': ['>50K',
#                                       {'fnlwgt <= 179896': ['<=50K',
#                                         '>50K']}]}]}]},
#                                 {'hours_per_week <= 39': ['<=50K',
#                                   {'occupation = Transport-moving': [{'race = Asian-Pac-Islander': ['>50K',
#                                       '<=50K']},
# ...
#                                               '>50K']}]}]},
#                                         {'marital_status = Divorced': [{'education_num <= 13': ['<=50K',
#                                             '>50K']},
#                                           '<=50K']}]}]},
#                                     {'fnlwgt <= 225612': [{'relationship = Not-in-family': [{'hours_per_week <= 35': [{'fnlwgt <= 198186': [{'fnlwgt <= 89041': [{'fnlwgt <= 74040': ['<=50K',
#                                                 '>50K']},
#                                               '<=50K']},
#                                             '>50K']},
#                                           {'age <= 63': [{'age <= 60': [{'education_num <= 13': [{'native_countr = Canada': ['>50K',
#                                                   {'occupation = Sales': ['>50K',
#                                                     {'marital_status = Married-spouse-absent': ['>50K',
#                                                       '<=50K']}]}]},
#                                                 {'marital_status = Divorced': [{'fnlwgt <= 194231': ['>50K',
#                                                     '<=50K']},
#                                                   {'native_countr = England': ['>50K',
#                                                     {'fnlwgt <= 48102': ['>50K',
#                                                       '<=50K']}]}]}]},
#                                               '>50K']},
#                                             {'hours_per_week <= 38': ['>50K',
#                                               '<=50K']}]}]},
#                                         {'age <= 47': [{'relationship = Unmarried': ['>50K',
#                                             '<=50K']},
#                                           '<=50K']}]},
#                                       '<=50K']}]},
#                                   '>50K']},
#                                 '<=50K']}]}]}]},
#                         '>50K']}]}]},
#                   {'sex = Male': [{'age <= 61': [{'education_num <= 15': [{'marital_status = Divorced': ['<=50K',
#                           '>50K']},
#                         {'hours_per_week <= 30': ['<=50K',
#                           {'marital_status = Never-married': [{'fnlwgt <= 162003': ['>50K',
#                               '<=50K']},
#                             '>50K']}]}]},
#                       '<=50K']},
#                     {'marital_status = Separated': ['>50K',
#                       {'hours_per_week <= 38': ['<=50K',
#                         {'relationship = Not-in-family': [{'fnlwgt <= 108037': ['<=50K',
#                             {'fnlwgt <= 194894': [{'occupation = Prof-specialty': [{'fnlwgt <= 176289': ['<=50K',
#                                   '>50K']},
#                                 '>50K']},
#                               '<=50K']}]},
#                           '<=50K']}]}]}]}]}]}]},
#             '>50K']},
#           {'capital_loss <= 2339': [{'education_num <= 14': [{'occupation = Exec-managerial': [{'marital_status = Never-married': [{'hours_per_week <= 45': [{'age <= 47': [{'native_countr = United-States': [{'sex = Male': ['<=50K',
#                           {'capital_loss <= 1741': [{'race = White': [{'relationship = Unmarried': ['>50K',
#                                 {'fnlwgt <= 175738': [{'education_num <= 13': [{'fnlwgt <= 158242': ['<=50K',
#                                       '>50K']},
#                                     '>50K']},
#                                   '<=50K']}]},
#                               '<=50K']},
#                             '>50K']}]},
#                         '>50K']},
#                       '>50K']},
#                     {'capital_loss <= 1564': [{'capital_gain <= 0': [{'hours_per_week <= 48': ['>50K',
#                           {'fnlwgt <= 86618': [{'fnlwgt <= 35032': ['<=50K',
#                               '>50K']},
#                             {'fnlwgt <= 128016': ['<=50K',
#                               {'relationship = Not-in-family': [{'fnlwgt <= 142712': ['>50K',
#                                   {'fnlwgt <= 153416': ['<=50K',
#                                     {'hours_per_week <= 55': [{'age <= 29': ['>50K',
#                                         {'fnlwgt <= 230224': [{'hours_per_week <= 50': [{'fnlwgt <= 204752': ['<=50K',
#                                               '>50K']},
#                                             '>50K']},
#                                           '<=50K']}]},
#                                       {'hours_per_week <= 60': [{'fnlwgt <= 357118': ['<=50K',
#                                           '>50K']},
#                                         {'workclass = Private': ['<=50K',
#                                           '>50K']}]}]}]}]},
#                                 '<=50K']}]}]}]},
#                         '<=50K']},
#                       '<=50K']}]},
#                   {'workclass = Self-emp-not-inc': [{'fnlwgt <= 275445': ['<=50K',
#                       '>50K']},
#                     {'fnlwgt <= 193755': [{'fnlwgt <= 171242': [{'workclass = Federal-gov': ['>50K',
#                           {'fnlwgt <= 168906': [{'age <= 59': [{'age <= 53': [{'hours_per_week <= 75': [{'marital_status = Married-spouse-absent': ['>50K',
#                                     {'age <= 37': [{'fnlwgt <= 150309': ['<=50K',
#                                         '>50K']},
#                                       {'fnlwgt <= 71691': [{'education_num <= 13': ['>50K',
#                                           '<=50K']},
#                                         {'fnlwgt <= 98475': ['<=50K',
#                                           {'fnlwgt <= 162236': [{'age <= 48': [{'relationship = Unmarried': ['<=50K',
#                                                 {'fnlwgt <= 112320': ['<=50K',
#                                                   '>50K']}]},
#                                               {'fnlwgt <= 100109': ['>50K',
#                                                 '<=50K']}]},
#                                             '<=50K']}]}]}]}]},
#                                   '>50K']},
#                                 '>50K']},
#                               '<=50K']},
#                             '<=50K']}]},
#                         '>50K']},
#                       {'fnlwgt <= 262777': [{'age <= 41': ['<=50K',
#                           {'hours_per_week <= 48': ['<=50K',
#                             {'hours_per_week <= 50': [{'fnlwgt <= 200949': ['<=50K',
#                                 '>50K']},
#                               '>50K']}]}]},
#                         {'workclass = Self-emp-inc': ['<=50K',
#                           {'fnlwgt <= 304512': ['>50K',
#                             {'fnlwgt <= 354923': [{'age <= 39': ['<=50K',
#                                 '>50K']},
#                               '>50K']}]}]}]}]}]}]},
#                 {'marital_status = Married-AF-spouse': ['>50K',
#                   {'fnlwgt <= 148437': [{'occupation = Adm-clerical': ['<=50K',
#                       {'hours_per_week <= 45': [{'fnlwgt <= 89325': ['<=50K',
#                           {'fnlwgt <= 116960': [{'fnlwgt <= 114758': [{'fnlwgt <= 94885': ['>50K',
#                                 '<=50K']},
#                               '>50K']},
#                             '<=50K']}]},
#                         {'age <= 67': [{'race = Asian-Pac-Islander': [{'age <= 35': ['>50K',
#                               '<=50K']},
#                             {'fnlwgt <= 27444': ['>50K',
#                               {'workclass = Local-gov': [{'sex = Male': [{'fnlwgt <= 45607': ['>50K',
#                                     '<=50K']},
#                                   '<=50K']},
#                                 {'native_countr = United-States': [{'age <= 49': [{'age <= 44': [{'capital_loss <= 0': [{'age <= 30': ['<=50K',
#                                           {'age <= 38': [{'hours_per_week <= 60': [{'workclass = Private': [{'fnlwgt <= 51259': [{'fnlwgt <= 29874': ['>50K',
#                                                     '<=50K']},
#                                                   {'marital_status = Never-married': ['<=50K',
#                                                     '>50K']}]},
#                                                 '<=50K']},
#                                               '>50K']},
#                                             {'age <= 42': ['<=50K',
#                                               {'fnlwgt <= 84141': [{'hours_per_week <= 65': ['<=50K',
#                                                   '>50K']},
#                                                 '>50K']}]}]}]},
#                                         '>50K']},
#                                       '<=50K']},
#                                     {'workclass = Self-emp-inc': ['>50K',
#                                       {'age <= 59': [{'occupation = Prof-specialty': [{'hours_per_week <= 50': ['>50K',
#                                             '<=50K']},
#                                           {'age <= 56': ['<=50K', '>50K']}]},
#                                         '<=50K']}]}]},
#                                   '<=50K']}]}]}]},
#                           '>50K']}]}]},
#                     {'age <= 61': [{'age <= 44': [{'relationship = Own-child': ['<=50K',
#                           {'workclass = Local-gov': [{'fnlwgt <= 198183': [{'fnlwgt <= 190368': [{'age <= 41': ['<=50K',
#                                   '>50K']},
#                                 '>50K']},
#                               '<=50K']},
#                             {'age <= 43': [{'occupation = Adm-clerical': [{'native_countr = Italy': ['>50K',
#                                   '<=50K']},
#                                 {'native_countr = United-States': [{'workclass = State-gov': ['<=50K',
#                                     {'fnlwgt <= 279173': [{'race = Black': ['<=50K',
#                                         {'race = White': [{'fnlwgt <= 229732': [{'capital_gain <= 0': [{'age <= 41': [{'hours_per_week <= 52': [{'fnlwgt <= 204984': [{'fnlwgt <= 180572': [{'fnlwgt <= 179641': [{'marital_status = Never-married': [{'occupation = Sales': ['>50K',
#                                                             '<=50K']},
#                                                           '<=50K']},
#                                                         '>50K']},
#                                                       '<=50K']},
#                                                     {'fnlwgt <= 207335': ['>50K',
#                                                       {'relationship = Unmarried': ['<=50K',
#                                                         {'hours_per_week <= 45': ['>50K',
#                                                           '<=50K']}]}]}]},
#                                                   {'marital_status = Divorced': [{'fnlwgt <= 179717': ['>50K',
#                                                       '<=50K']},
#                                                     {'fnlwgt <= 164519': ['<=50K',
#                                                       '>50K']}]}]},
#                                                 '<=50K']},
#                                               '<=50K']},
#                                             {'age <= 36': ['<=50K', '>50K']}]},
#                                           '>50K']}]},
#                                       {'capital_loss <= 0': [{'marital_status = Separated': ['>50K',
#                                           {'workclass = Self-emp-inc': ['>50K',
#                                             {'fnlwgt <= 320077': [{'age <= 38': [{'occupation = Prof-specialty': ['<=50K',
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               {'relationship = Not-in-family': [{'hours_per_week <= 50': [{'workclass = Federal-gov': ['<=50K',
#                                                     {'occupation = Tech-support': ['>50K',
#                                                       {'hours_per_week <= 48': ['<=50K',
#                                                         {'age <= 31': [{'fnlwgt <= 381645': ['<=50K',
#                                                             '>50K']},
#                                                           {'fnlwgt <= 377798': ['>50K',
#                                                             '<=50K']}]}]}]}]},
#                                                   '<=50K']},
#                                                 '<=50K']}]}]}]},
#                                         '<=50K']}]}]},
#                                   {'native_countr = Greece': ['>50K',
#                                     '<=50K']}]}]},
#                               '<=50K']}]}]},
#                         {'race = White': [{'fnlwgt <= 343333': [{'occupation = Sales': [{'fnlwgt <= 231196': [{'fnlwgt <= 216475': [{'age <= 51': [{'hours_per_week <= 45': ['<=50K',
#                                       '>50K']},
#                                     '<=50K']},
#                                   '<=50K']},
#                                 '>50K']},
#                               {'fnlwgt <= 285730': [{'fnlwgt <= 171807': [{'hours_per_week <= 56': [{'education_num <= 13': ['>50K',
#                                       {'capital_loss <= 0': [{'sex = Male': ['>50K',
#                                           '<=50K']},
#                                         '>50K']}]},
#                                     '<=50K']},
#                                   {'sex = Male': [{'age <= 48': [{'hours_per_week <= 50': [{'occupation = Other-service': ['>50K',
#                                           {'education_num <= 13': ['<=50K',
#                                             '>50K']}]},
#                                         '<=50K']},
#                                       '<=50K']},
#                                     {'age <= 58': ['<=50K', '>50K']}]}]},
#                                 {'occupation = Adm-clerical': ['>50K',
#                                   {'fnlwgt <= 321851': [{'hours_per_week <= 60': [{'capital_loss <= 1564': ['>50K',
#                                         '<=50K']},
#                                       '<=50K']},
#                                     '<=50K']}]}]}]},
#                             '<=50K']},
#                           '>50K']}]},
#                       '<=50K']}]}]}]},
#               {'age <= 32': [{'native_countr = United-States': [{'hours_per_week <= 60': [{'marital_status = Never-married': [{'fnlwgt <= 72630': ['<=50K',
#                         {'fnlwgt <= 76714': ['>50K', '<=50K']}]},
#                       '>50K']},
#                     '<=50K']},
#                   '>50K']},
#                 {'age <= 58': [{'workclass = Self-emp-not-inc': ['>50K',
#                     {'hours_per_week <= 70': [{'relationship = Other-relative': ['<=50K',
#                         {'fnlwgt <= 37869': ['<=50K',
#                           {'age <= 45': [{'fnlwgt <= 111499': ['>50K',
#                               {'age <= 35': ['>50K',
#                                 {'age <= 39': ['<=50K',
#                                   {'workclass = State-gov': ['<=50K',
#                                     {'hours_per_week <= 50': ['>50K',
#                                       '<=50K']}]}]}]}]},
#                             {'fnlwgt <= 71772': [{'sex = Male': ['<=50K',
#                                 '>50K']},
#                               '>50K']}]}]}]},
#                       '<=50K']}]},
#                   {'occupation = Prof-specialty': [{'relationship = Unmarried': ['>50K',
#                       '<=50K']},
#                     '>50K']}]}]}]},
#             '>50K']}]}]}]},
#     {'capital_gain <= 7978': [{'capital_gain <= 7430': ['>50K',
#         {'workclass = Local-gov': ['>50K', '<=50K']}]},
#       {'age <= 19': ['<=50K',
#         {'workclass = Self-emp-not-inc': [{'age <= 54': ['>50K',
#             {'hours_per_week <= 55': ['>50K', '<=50K']}]},
#           '>50K']}]}]}]}]}

# %%
count_depth(tree)
# Out:
# 80

# %%
count_nodes(tree)
# Out:
# 6533

# %%
pruned_tree = post_pruning(tree ,df_train,df_test)

# %%
pruned_tree
# Out:
# {'marital_status = Married-civ-spouse': [{'education_num <= 11': [{'capital_gain <= 5013': [{'education_num <= 8': [{'hours_per_week <= 40': [{'education_num <= 5': [{'hours_per_week <= 24': ['<=50K',
#               {'native_countr = Yugoslavia': ['>50K',
#                 {'workclass = Self-emp-inc': ['<=50K',
#                   {'occupation = Handlers-cleaners': ['<=50K',
#                     {'occupation = Prof-specialty': ['<=50K',
#                       {'relationship = Wife': ['<=50K',
#                         {'fnlwgt <= 144594': ['<=50K',
#                           {'occupation = Exec-managerial': ['<=50K',
#                             {'fnlwgt <= 155106': ['<=50K',
#                               {'capital_loss <= 1672': ['<=50K',
#                                 {'capital_loss <= 1902': ['>50K',
#                                   '<=50K']}]}]}]}]}]}]}]}]}]}]},
#             {'age <= 37': ['<=50K',
#               {'capital_loss <= 1740': [{'age <= 66': [{'age <= 38': ['<=50K',
#                     {'age <= 39': ['<=50K',
#                       {'native_countr = Japan': ['>50K',
#                         {'native_countr = United-States': [{'capital_gain <= 3942': ['<=50K',
#                             '>50K']},
#                           '<=50K']}]}]}]},
#                   '<=50K']},
#                 {'capital_loss <= 1902': ['>50K', '<=50K']}]}]}]},
#           {'occupation = Exec-managerial': ['<=50K',
#             {'occupation = Other-service': ['<=50K',
#               {'age <= 27': [{'education = 11th': [{'fnlwgt <= 212888': ['<=50K',
#                     {'fnlwgt <= 235071': ['>50K', '<=50K']}]},
#                   '<=50K']},
#                 '<=50K']}]}]}]},
#         {'capital_loss <= 1844': [{'age <= 33': [{'age <= 24': ['<=50K',
#               {'education_num <= 9': [{'hours_per_week <= 37': ['<=50K',
#                   {'occupation = Exec-managerial': ['<=50K',
#                     {'occupation = Protective-serv': [{'age <= 31': [{'fnlwgt <= 326104': [{'workclass = State-gov': ['<=50K',
#                             {'fnlwgt <= 199172': ['<=50K', '>50K']}]},
#                           '<=50K']},
#                         '<=50K']},
#                       {'race = Black': ['<=50K',
#                         {'native_countr = Ireland': ['>50K',
#                           {'occupation = Tech-support': [{'hours_per_week <= 40': ['<=50K',
#                               '>50K']},
#                             {'occupation = Sales': ['<=50K',
#                               {'workclass = Self-emp-not-inc': ['<=50K',
#                                 {'fnlwgt <= 271276': [{'capital_gain <= 3942': [{'fnlwgt <= 103596': ['<=50K',
#                                       {'occupation = Prof-specialty': [{'native_countr = United-States': [{'age <= 31': ['>50K',
#                                             '<=50K']},
#                                           '<=50K']},
#                                         {'race = White': [{'age <= 29': ['<=50K',
#                                             {'hours_per_week <= 77': [{'fnlwgt <= 103651': ['>50K',
#                                                 {'fnlwgt <= 204577': [{'occupation = Other-service': ['<=50K',
#                                                     {'capital_gain <= 0': [{'fnlwgt <= 196266': [{'fnlwgt <= 195000': [{'workclass = Private': [{'hours_per_week <= 50': [{'fnlwgt <= 136651': [{'fnlwgt <= 114691': [{'fnlwgt <= 108256': ['<=50K',
#                                                                     {'hours_per_week <= 40': ['>50K',
#                                                                       '<=50K']}]},
#                                                                   '<=50K']},
#                                                                 {'fnlwgt <= 140206': ['>50K',
#                                                                   {'occupation = Handlers-cleaners': [{'fnlwgt <= 161599': ['>50K',
#                                                                       '<=50K']},
#                                                                     {'fnlwgt <= 170017': [{'fnlwgt <= 158291': [{'fnlwgt <= 152156': ['<=50K',
#                                                                           {'occupation = Craft-repair': ['>50K',
#                                                                             '<=50K']}]},
#                                                                         '<=50K']},
#                                                                       '<=50K']}]}]}]},
#                                                               '<=50K']},
#                                                             {'age <= 32': [{'fnlwgt <= 127651': ['>50K',
#                                                                 {'fnlwgt <= 157990': ['<=50K',
#                                                                   '>50K']}]},
#                                                               '<=50K']}]},
#                                                           '>50K']},
#                                                         '<=50K']},
#                                                       '<=50K']}]},
#                                                   '<=50K']}]},
#                                               '>50K']}]},
#                                           '<=50K']}]}]},
#                                     {'capital_gain <= 4386': ['>50K',
#                                       '<=50K']}]},
#                                   '<=50K']}]}]}]}]}]}]}]}]},
#                 {'workclass = Federal-gov': [{'age <= 26': ['<=50K',
#                     {'age <= 29': ['>50K', '<=50K']}]},
#                   {'fnlwgt <= 152351': [{'relationship = Husband': [{'hours_per_week <= 36': ['<=50K',
#                         {'age <= 31': ['<=50K',
#                           {'hours_per_week <= 45': ['<=50K',
#                             {'fnlwgt <= 113838': [{'occupation = Exec-managerial': ['>50K',
#                                 '<=50K']},
#                               {'hours_per_week <= 55': ['>50K',
#                                 '<=50K']}]}]}]}]},
#                       '<=50K']},
#                     {'capital_gain <= 3103': [{'capital_gain <= 2885': [{'age <= 29': [{'hours_per_week <= 25': ['<=50K',
#                             {'relationship = Wife': ['<=50K',
#                               {'race = Black': ['<=50K',
#                                 {'fnlwgt <= 330695': [{'fnlwgt <= 250038': [{'occupation = Machine-op-inspct': ['<=50K',
#                                       {'fnlwgt <= 190628': [{'fnlwgt <= 183523': [{'fnlwgt <= 182308': [{'hours_per_week <= 40': ['<=50K',
#                                               {'occupation = Tech-support': ['>50K',
#                                                 {'fnlwgt <= 155057': ['>50K',
#                                                   '<=50K']}]}]},
#                                             '>50K']},
#                                           '<=50K']},
#                                         '<=50K']}]},
#                                     '<=50K']},
#                                   '<=50K']}]}]}]},
#                           {'occupation = Exec-managerial': [{'hours_per_week <= 35': ['>50K',
#                               {'relationship = Husband': [{'fnlwgt <= 158438': ['>50K',
#                                   {'fnlwgt <= 180303': ['<=50K', '>50K']}]},
#                                 '<=50K']}]},
#                             {'native_countr = United-States': [{'hours_per_week <= 18': ['<=50K',
#                                 {'hours_per_week <= 75': [{'hours_per_week <= 24': ['>50K',
#                                     {'hours_per_week <= 60': [{'hours_per_week <= 52': [{'occupation = Other-service': ['<=50K',
#                                           {'capital_loss <= 0': [{'occupation = Adm-clerical': [{'fnlwgt <= 286911': ['<=50K',
#                                                 '>50K']},
#                                               {'fnlwgt <= 264554': [{'fnlwgt <= 259301': [{'fnlwgt <= 236379': [{'fnlwgt <= 231263': [{'fnlwgt <= 218551': [{'fnlwgt <= 199248': [{'fnlwgt <= 196385': [{'fnlwgt <= 187560': [{'fnlwgt <= 176998': [{'fnlwgt <= 176862': [{'fnlwgt <= 172304': [{'hours_per_week <= 45': [{'occupation = Sales': ['>50K',
#                                                                         '<=50K']},
#                                                                       '>50K']},
#                                                                     '<=50K']},
#                                                                   '>50K']},
#                                                                 '<=50K']},
#                                                               '>50K']},
#                                                             '<=50K']},
#                                                           '>50K']},
#                                                         '<=50K']},
#                                                       '>50K']},
#                                                     '<=50K']},
#                                                   '>50K']},
#                                                 '<=50K']}]},
#                                             '<=50K']}]},
#                                         '>50K']},
#                                       '<=50K']}]},
#                                   '>50K']}]},
#                               {'fnlwgt <= 395170': ['<=50K',
#                                 {'native_countr = Peru': ['>50K',
#                                   {'occupation = Tech-support': ['>50K',
#                                     '<=50K']}]}]}]}]}]},
#                         '>50K']},
#                       '<=50K']}]}]}]}]},
#             {'hours_per_week <= 34': [{'education_num <= 9': [{'relationship = Wife': [{'fnlwgt <= 95577': ['<=50K',
#                     {'age <= 47': [{'age <= 44': ['<=50K', '>50K']},
#                       '<=50K']}]},
#                   '<=50K']},
#                 '<=50K']},
#               {'education_num <= 9': [{'occupation = Other-service': ['<=50K',
#                   {'occupation = Farming-fishing': ['<=50K',
#                     {'age <= 36': [{'hours_per_week <= 45': ['<=50K',
#                         {'hours_per_week <= 65': [{'fnlwgt <= 283921': [{'workclass = State-gov': ['>50K',
#                               {'fnlwgt <= 261241': [{'workclass = Self-emp-not-inc': ['<=50K',
#                                   {'capital_gain <= 0': [{'occupation = Tech-support': ['<=50K',
#                                       {'fnlwgt <= 30267': ['<=50K',
#                                         {'occupation = Adm-clerical': ['>50K',
#                                           {'fnlwgt <= 46492': ['>50K',
#                                             {'fnlwgt <= 76417': ['<=50K',
#                                               {'native_countr = Iran': ['>50K',
#                                                 {'hours_per_week <= 46': ['>50K',
#                                                   {'occupation = Protective-serv': ['>50K',
#                                                     {'fnlwgt <= 260560': [{'fnlwgt <= 89508': ['>50K',
#                                                         {'hours_per_week <= 50': [{'fnlwgt <= 111985': ['>50K',
#                                                             '<=50K']},
#                                                           {'hours_per_week <= 54': ['>50K',
#                                                             {'fnlwgt <= 259846': [{'fnlwgt <= 190023': [{'fnlwgt <= 186531': [{'occupation = Transport-moving': ['<=50K',
#                                                                     {'fnlwgt <= 182863': ['>50K',
#                                                                       '<=50K']}]},
#                                                                   '>50K']},
#                                                                 '<=50K']},
#                                                               '>50K']}]}]}]},
#                                                       '>50K']}]}]}]}]}]}]}]}]},
#                                     '<=50K']}]},
#                                 '<=50K']}]},
#                             '>50K']},
#                           '<=50K']}]},
#                       {'capital_loss <= 1485': [{'occupation = Exec-managerial': [{'fnlwgt <= 334291': [{'workclass = Self-emp-not-inc': ['<=50K',
#                               '>50K']},
#                             '>50K']},
#                           {'capital_gain <= 4386': [{'native_countr = Mexico': ['<=50K',
#                               {'workclass = Self-emp-not-inc': ['<=50K',
#                                 {'capital_gain <= 4064': [{'capital_gain <= 3103': [{'capital_gain <= 2885': [{'capital_gain <= 0': [{'hours_per_week <= 46': [{'age <= 59': [{'age <= 42': [{'occupation = Tech-support': ['>50K',
#                                                 {'fnlwgt <= 29702': ['>50K',
#                                                   {'workclass = State-gov': ['<=50K',
#                                                     {'occupation = Adm-clerical': [{'race = White': [{'age <= 41': [{'sex = Male': ['<=50K',
#                                                             '>50K']},
#                                                           '<=50K']},
#                                                         '<=50K']},
#                                                       {'hours_per_week <= 35': ['<=50K',
#                                                         {'fnlwgt <= 365465': [{'native_countr = El-Salvador': ['>50K',
#                                                             {'native_countr = Canada': ['>50K',
#                                                               {'fnlwgt <= 107563': ['<=50K',
#                                                                 {'fnlwgt <= 116736': ['<=50K',
#                                                                   {'occupation = Sales': [{'fnlwgt <= 126954': ['>50K',
#                                                                       {'hours_per_week <= 43': [{'hours_per_week <= 40': [{'age <= 40': ['>50K',
#                                                                             {'sex = Male': ['<=50K',
#                                                                               '>50K']}]},
#                                                                           '>50K']},
#                                                                         '<=50K']}]},
#                                                                     {'fnlwgt <= 195124': ['<=50K',
#                                                                       {'fnlwgt <= 198096': ['>50K',
#                                                                         {'fnlwgt <= 201520': ['<=50K',
#                                                                           {'fnlwgt <= 239171': [{'fnlwgt <= 236648': [{'workclass = Local-gov': ['>50K',
#                                                                                 '<=50K']},
#                                                                               '>50K']},
#                                                                             '<=50K']}]}]}]}]}]}]}]}]},
#                                                           '>50K']}]}]}]}]}]},
#                                               {'workclass = Federal-gov': [{'hours_per_week <= 37': ['<=50K',
#                                                   '>50K']},
#                                                 {'relationship = Other-relative': ['<=50K',
#                                                   {'native_countr = South': ['>50K',
#                                                     {'native_countr = Germany': ['>50K',
#                                                       {'age <= 52': [{'relationship = Own-child': ['>50K',
#                                                           {'fnlwgt <= 85995': ['<=50K',
#                                                             {'native_countr = United-States': [{'hours_per_week <= 42': ['<=50K',
#                                                                 {'age <= 46': [{'occupation = Craft-repair': ['<=50K',
#                                                                     {'fnlwgt <= 230684': [{'occupation = Transport-moving': ['<=50K',
#                                                                         '>50K']},
#                                                                       '>50K']}]},
#                                                                   '<=50K']}]},
#                                                               '<=50K']}]}]},
#                                                         '<=50K']}]}]}]}]}]},
#                                             '<=50K']},
#                                           {'hours_per_week <= 85': [{'occupation = Tech-support': ['>50K',
#                                               {'fnlwgt <= 102828': [{'workclass = Self-emp-inc': ['<=50K',
#                                                   {'hours_per_week <= 50': ['<=50K',
#                                                     {'age <= 39': ['<=50K',
#                                                       {'hours_per_week <= 56': ['>50K',
#                                                         '<=50K']}]}]}]},
#                                                 {'fnlwgt <= 120131': [{'fnlwgt <= 117917': [{'age <= 59': [{'age <= 38': ['>50K',
#                                                         '<=50K']},
#                                                       '>50K']},
#                                                     '>50K']},
#                                                   {'workclass = Private': [{'age <= 42': [{'age <= 39': [{'fnlwgt <= 204527': [{'age <= 38': ['<=50K',
#                                                             '>50K']},
#                                                           '>50K']},
#                                                         {'fnlwgt <= 199018': [{'fnlwgt <= 197919': [{'occupation = Craft-repair': ['>50K',
#                                                               '<=50K']},
#                                                             '>50K']},
#                                                           '<=50K']}]},
#                                                       {'age <= 58': [{'occupation = Prof-specialty': ['<=50K',
#                                                           {'age <= 49': [{'occupation = Craft-repair': ['<=50K',
#                                                               {'fnlwgt <= 176063': ['>50K',
#                                                                 {'fnlwgt <= 184105': ['<=50K',
#                                                                   '>50K']}]}]},
#                                                             {'occupation = Machine-op-inspct': ['<=50K',
#                                                               {'occupation = Transport-moving': ['<=50K',
#                                                                 {'fnlwgt <= 146551': ['>50K',
#                                                                   {'occupation = Adm-clerical': ['<=50K',
#                                                                     {'age <= 51': ['<=50K',
#                                                                       {'age <= 56': ['>50K',
#                                                                         '<=50K']}]}]}]}]}]}]}]},
#                                                         '<=50K']}]},
#                                                     {'sex = Male': [{'occupation = Transport-moving': ['<=50K',
#                                                         '>50K']},
#                                                       '<=50K']}]}]}]}]},
#                                             '<=50K']}]},
#                                         '<=50K']},
#                                       '>50K']},
#                                     '<=50K']},
#                                   '>50K']}]}]},
#                             '<=50K']}]},
#                         '<=50K']}]}]}]},
#                 {'workclass = Self-emp-not-inc': [{'fnlwgt <= 352712': ['<=50K',
#                     {'occupation = Sales': ['>50K',
#                       {'age <= 54': [{'hours_per_week <= 40': [{'fnlwgt <= 409189': ['>50K',
#                             '<=50K']},
#                           '<=50K']},
#                         '>50K']}]}]},
#                   {'occupation = Exec-managerial': [{'fnlwgt <= 130126': [{'fnlwgt <= 24106': ['>50K',
#                         {'hours_per_week <= 40': [{'age <= 58': [{'race = White': [{'age <= 43': ['<=50K',
#                                 {'workclass = Federal-gov': ['>50K',
#                                   {'fnlwgt <= 106113': ['>50K', '<=50K']}]}]},
#                               '>50K']},
#                             '>50K']},
#                           {'native_countr = United-States': [{'age <= 59': [{'fnlwgt <= 82622': ['>50K',
#                                 {'fnlwgt <= 95835': ['>50K',
#                                   {'fnlwgt <= 97771': ['<=50K',
#                                     {'workclass = Self-emp-inc': ['>50K',
#                                       {'fnlwgt <= 108293': ['>50K',
#                                         {'fnlwgt <= 111377': ['<=50K',
#                                           '>50K']}]}]}]}]}]},
#                               '<=50K']},
#                             '<=50K']}]}]},
#                       {'age <= 34': ['>50K',
#                         {'fnlwgt <= 138991': ['>50K',
#                           {'fnlwgt <= 152909': [{'hours_per_week <= 40': ['>50K',
#                               '<=50K']},
#                             {'hours_per_week <= 40': [{'sex = Male': [{'age <= 35': ['<=50K',
#                                   {'fnlwgt <= 173968': ['>50K',
#                                     {'fnlwgt <= 198223': ['<=50K',
#                                       {'fnlwgt <= 214541': ['>50K',
#                                         {'fnlwgt <= 266138': [{'workclass = Self-emp-inc': ['>50K',
#                                             {'education_num <= 10': [{'age <= 48': ['<=50K',
#                                                 '>50K']},
#                                               '<=50K']}]},
#                                           {'fnlwgt <= 280798': ['>50K',
#                                             {'workclass = Self-emp-inc': ['>50K',
#                                               {'fnlwgt <= 284616': ['<=50K',
#                                                 {'fnlwgt <= 313022': ['>50K',
#                                                   '<=50K']}]}]}]}]}]}]}]}]},
#                                 '>50K']},
#                               {'age <= 46': [{'education_num <= 10': [{'age <= 35': ['<=50K',
#                                     '>50K']},
#                                   '>50K']},
#                                 '>50K']}]}]}]}]}]},
#                     {'occupation = Handlers-cleaners': [{'fnlwgt <= 203070': ['<=50K',
#                         {'race = White': [{'fnlwgt <= 353824': [{'hours_per_week <= 48': ['>50K',
#                               '<=50K']},
#                             '<=50K']},
#                           '<=50K']}]},
#                       {'occupation = Other-service': ['<=50K',
#                         {'capital_gain <= 4386': [{'occupation = Farming-fishing': [{'fnlwgt <= 176186': [{'education_num <= 10': ['<=50K',
#                                 '>50K']},
#                               '<=50K']},
#                             {'fnlwgt <= 168191': [{'occupation = Tech-support': ['>50K',
#                                 {'workclass = Self-emp-inc': [{'age <= 56': ['>50K',
#                                     '<=50K']},
#                                   {'occupation = Prof-specialty': [{'fnlwgt <= 158688': [{'workclass = Federal-gov': ['>50K',
#                                         '<=50K']},
#                                       '>50K']},
#                                     {'hours_per_week <= 36': ['<=50K',
#                                       {'age <= 44': [{'workclass = State-gov': ['<=50K',
#                                           {'fnlwgt <= 135304': [{'fnlwgt <= 132222': [{'capital_gain <= 2829': [{'fnlwgt <= 126845': [{'fnlwgt <= 123557': [{'fnlwgt <= 118358': [{'hours_per_week <= 55': [{'hours_per_week <= 48': ['<=50K',
#                                                           {'fnlwgt <= 78247': ['<=50K',
#                                                             '>50K']}]},
#                                                         '<=50K']},
#                                                       '<=50K']},
#                                                     {'age <= 40': ['>50K',
#                                                       '<=50K']}]},
#                                                   '<=50K']},
#                                                 '>50K']},
#                                               '<=50K']},
#                                             '<=50K']}]},
#                                         {'fnlwgt <= 30447': ['<=50K',
#                                           {'fnlwgt <= 43221': [{'hours_per_week <= 47': [{'age <= 45': ['<=50K',
#                                                 {'workclass = Private': ['>50K',
#                                                   '<=50K']}]},
#                                               '<=50K']},
#                                             {'race = White': [{'fnlwgt <= 145409': [{'fnlwgt <= 138999': ['<=50K',
#                                                   '>50K']},
#                                                 {'age <= 46': [{'hours_per_week <= 44': ['<=50K',
#                                                     '>50K']},
#                                                   '<=50K']}]},
#                                               {'fnlwgt <= 81132': ['<=50K',
#                                                 {'fnlwgt <= 117872': ['>50K',
#                                                   {'hours_per_week <= 40': ['<=50K',
#                                                     '>50K']}]}]}]}]}]}]}]}]}]}]},
#                               {'capital_loss <= 1485': [{'workclass = Private': [{'age <= 45': [{'hours_per_week <= 40': [{'fnlwgt <= 173316': ['<=50K',
#                                         {'occupation = Transport-moving': ['<=50K',
#                                           {'fnlwgt <= 454843': [{'occupation = Machine-op-inspct': ['<=50K',
#                                               {'occupation = Adm-clerical': ['<=50K',
#                                                 {'fnlwgt <= 377622': [{'native_countr = Japan': ['<=50K',
#                                                     {'fnlwgt <= 361888': [{'hours_per_week <= 38': ['>50K',
#                                                         {'fnlwgt <= 184105': [{'sex = Male': [{'age <= 43': ['>50K',
#                                                               '<=50K']},
#                                                             '<=50K']},
#                                                           {'fnlwgt <= 193524': ['<=50K',
#                                                             {'fnlwgt <= 211580': ['>50K',
#                                                               {'fnlwgt <= 224799': ['<=50K',
#                                                                 {'native_countr = Philippines': ['<=50K',
#                                                                   {'fnlwgt <= 226081': ['>50K',
#                                                                     {'native_countr = Vietnam': ['<=50K',
#                                                                       {'age <= 43': [{'education_num <= 10': ['<=50K',
#                                                                           '>50K']},
#                                                                         {'occupation = Craft-repair': ['<=50K',
#                                                                           '>50K']}]}]}]}]}]}]}]}]}]},
#                                                       '<=50K']}]},
#                                                   '>50K']}]}]},
#                                             '<=50K']}]}]},
#                                       {'hours_per_week <= 48': [{'hours_per_week <= 45': [{'sex = Male': [{'race = White': [{'fnlwgt <= 222596': [{'age <= 37': ['>50K',
#                                                   {'age <= 41': ['<=50K',
#                                                     '>50K']}]},
#                                                 '<=50K']},
#                                               '>50K']},
#                                             '>50K']},
#                                           '>50K']},
#                                         {'age <= 42': ['<=50K', '>50K']}]}]},
#                                     {'fnlwgt <= 170287': ['>50K',
#                                       {'fnlwgt <= 343849': [{'sex = Male': [{'hours_per_week <= 35': ['<=50K',
#                                             {'fnlwgt <= 340982': [{'race = Black': ['>50K',
#                                                 {'fnlwgt <= 330416': [{'age <= 66': [{'occupation = Adm-clerical': ['<=50K',
#                                                       {'age <= 55': [{'fnlwgt <= 202956': [{'fnlwgt <= 199058': [{'fnlwgt <= 197702': ['<=50K',
#                                                               '>50K']},
#                                                             '<=50K']},
#                                                           '>50K']},
#                                                         {'occupation = Tech-support': ['>50K',
#                                                           {'occupation = Sales': ['>50K',
#                                                             {'fnlwgt <= 299616': [{'hours_per_week <= 40': [{'fnlwgt <= 204751': [{'fnlwgt <= 180636': ['<=50K',
#                                                                     '>50K']},
#                                                                   '<=50K']},
#                                                                 '<=50K']},
#                                                               '>50K']}]}]}]}]},
#                                                     '>50K']},
#                                                   '>50K']}]},
#                                               '<=50K']}]},
#                                           {'fnlwgt <= 318351': ['>50K',
#                                             '<=50K']}]},
#                                         '>50K']}]}]},
#                                   '>50K']},
#                                 '<=50K']}]}]},
#                           '<=50K']}]}]}]}]}]}]}]},
#           {'capital_loss <= 1977': ['>50K',
#             {'capital_loss <= 2149': ['<=50K',
#               {'capital_loss <= 2415': [{'capital_loss <= 2377': [{'age <= 52': ['<=50K',
#                     {'occupation = Farming-fishing': ['<=50K', '>50K']}]},
#                   '>50K']},
#                 '<=50K']}]}]}]}]},
#       {'age <= 60': ['>50K',
#         {'hours_per_week <= 45': [{'capital_gain <= 6514': ['>50K',
#             {'capital_gain <= 6767': ['<=50K',
#               {'capital_gain <= 9386': ['>50K',
#                 {'capital_gain <= 10566': ['<=50K', '>50K']}]}]}]},
#           '>50K']}]}]},
#     {'capital_gain <= 5013': [{'capital_loss <= 1740': [{'age <= 33': [{'age <= 24': ['<=50K',
#             {'hours_per_week <= 41': [{'hours_per_week <= 30': [{'relationship = Wife': ['<=50K',
#                   {'occupation = Other-service': ['>50K',
#                     {'education = Prof-school': ['>50K',
#                       {'age <= 32': ['<=50K',
#                         {'hours_per_week <= 20': ['<=50K', '>50K']}]}]}]}]},
#                 {'age <= 28': [{'native_countr = Hong': ['>50K',
#                     {'fnlwgt <= 478277': [{'occupation = Sales': [{'education_num <= 13': [{'fnlwgt <= 154941': ['>50K',
#                             '<=50K']},
#                           '<=50K']},
#                         {'fnlwgt <= 81648': ['<=50K',
#                           {'fnlwgt <= 84619': ['>50K',
#                             {'hours_per_week <= 37': ['<=50K',
#                               {'fnlwgt <= 359155': [{'fnlwgt <= 102460': ['<=50K',
#                                   {'workclass = Local-gov': ['>50K',
#                                     {'age <= 25': ['<=50K',
#                                       {'occupation = Craft-repair': ['<=50K',
#                                         {'education_num <= 12': ['<=50K',
#                                           {'fnlwgt <= 135296': ['>50K',
#                                             {'occupation = Tech-support': ['>50K',
#                                               {'native_countr = Cuba': ['>50K',
#                                                 {'native_countr = United-States': [{'occupation = Transport-moving': ['>50K',
#                                                     {'education_num <= 15': [{'fnlwgt <= 302903': [{'fnlwgt <= 263614': [{'age <= 27': ['<=50K',
#                                                             '>50K']},
#                                                           '<=50K']},
#                                                         '>50K']},
#                                                       '>50K']}]},
#                                                   '<=50K']}]}]}]}]}]}]}]}]},
#                                 '<=50K']}]}]}]}]},
#                       '>50K']}]},
#                   {'fnlwgt <= 444304': [{'fnlwgt <= 211880': [{'fnlwgt <= 146161': [{'capital_loss <= 1485': [{'race = White': ['>50K',
#                             '<=50K']},
#                           '<=50K']},
#                         {'native_countr = United-States': [{'fnlwgt <= 167474': ['<=50K',
#                             {'education = Bachelors': ['>50K', '<=50K']}]},
#                           '<=50K']}]},
#                       {'fnlwgt <= 217460': ['>50K',
#                         {'native_countr = United-States': [{'age <= 29': ['>50K',
#                             {'occupation = Other-service': ['<=50K',
#                               '>50K']}]},
#                           {'occupation = Exec-managerial': ['>50K',
#                             '<=50K']}]}]}]},
#                     '<=50K']}]}]},
#               {'occupation = Exec-managerial': [{'age <= 29': [{'fnlwgt <= 90196': ['>50K',
#                     {'education_num <= 12': ['<=50K',
#                       {'sex = Male': [{'fnlwgt <= 216178': [{'fnlwgt <= 144133': [{'fnlwgt <= 115945': ['>50K',
#                               '<=50K']},
#                             {'hours_per_week <= 55': ['>50K', '<=50K']}]},
#                           '<=50K']},
#                         '>50K']}]}]},
#                   '>50K']},
#                 {'education_num <= 12': ['<=50K',
#                   {'fnlwgt <= 119628': [{'workclass = Local-gov': ['<=50K',
#                       {'education = Prof-school': ['>50K',
#                         {'fnlwgt <= 29933': ['>50K',
#                           {'fnlwgt <= 34574': ['<=50K',
#                             {'occupation = Sales': [{'workclass = Self-emp-not-inc': ['<=50K',
#                                 '>50K']},
#                               '<=50K']}]}]}]}]},
#                     {'fnlwgt <= 181920': [{'education = Prof-school': ['>50K',
#                         {'native_countr = Italy': ['<=50K',
#                           {'native_countr = Germany': ['<=50K',
#                             {'hours_per_week <= 44': ['>50K',
#                               {'fnlwgt <= 122889': ['>50K',
#                                 {'fnlwgt <= 123253': ['<=50K',
#                                   {'fnlwgt <= 177695': [{'fnlwgt <= 176972': [{'race = White': [{'hours_per_week <= 48': ['>50K',
#                                           {'occupation = Tech-support': ['<=50K',
#                                             '>50K']}]},
#                                         '>50K']},
#                                       '<=50K']},
#                                     '>50K']}]}]}]}]}]}]},
#                       '>50K']}]}]}]}]}]},
#           {'hours_per_week <= 30': [{'sex = Male': [{'race = Asian-Pac-Islander': ['<=50K',
#                 {'education_num <= 14': [{'occupation = Tech-support': ['>50K',
#                     '<=50K']},
#                   {'occupation = Prof-specialty': [{'hours_per_week <= 10': ['>50K',
#                       {'hours_per_week <= 23': [{'fnlwgt <= 179574': ['>50K',
#                           '<=50K']},
#                         {'age <= 62': ['>50K',
#                           {'fnlwgt <= 172370': ['<=50K', '>50K']}]}]}]},
#                     '<=50K']}]}]},
#               {'fnlwgt <= 83508': ['<=50K',
#                 {'age <= 49': ['>50K',
#                   {'fnlwgt <= 202384': ['<=50K', '>50K']}]}]}]},
#             {'occupation = Other-service': ['<=50K',
#               {'capital_gain <= 4386': [{'workclass = Self-emp-not-inc': [{'education = Prof-school': [{'occupation = Craft-repair': ['<=50K',
#                       {'age <= 64': ['>50K', '<=50K']}]},
#                     {'occupation = Farming-fishing': ['<=50K',
#                       {'race = White': [{'education_num <= 12': ['<=50K',
#                           {'age <= 40': [{'relationship = Husband': [{'native_countr = Canada': ['>50K',
#                                 {'native_countr = Dominican-Republic': ['>50K',
#                                   {'age <= 37': [{'hours_per_week <= 40': ['<=50K',
#                                       '>50K']},
#                                     {'fnlwgt <= 199303': ['<=50K',
#                                       {'fnlwgt <= 336793': ['>50K',
#                                         '<=50K']}]}]}]}]},
#                               '>50K']},
#                             {'age <= 58': [{'fnlwgt <= 277434': [{'hours_per_week <= 42': [{'age <= 53': [{'fnlwgt <= 203098': [{'fnlwgt <= 127151': [{'age <= 52': ['>50K',
#                                           '<=50K']},
#                                         '<=50K']},
#                                       '>50K']},
#                                     '>50K']},
#                                   {'fnlwgt <= 263568': [{'age <= 41': ['>50K',
#                                       {'fnlwgt <= 98829': ['<=50K',
#                                         {'age <= 48': [{'hours_per_week <= 52': [{'age <= 46': ['>50K',
#                                               '<=50K']},
#                                             '<=50K']},
#                                           {'fnlwgt <= 156800': ['<=50K',
#                                             {'fnlwgt <= 242606': ['>50K',
#                                               '<=50K']}]}]}]}]},
#                                     '<=50K']}]},
#                                 '>50K']},
#                               {'occupation = Exec-managerial': ['<=50K',
#                                 '>50K']}]}]}]},
#                         '<=50K']}]}]},
#                   {'education_num <= 13': [{'occupation = Exec-managerial': [{'capital_loss <= 0': [{'age <= 62': [{'fnlwgt <= 73199': [{'hours_per_week <= 40': ['<=50K',
#                               '>50K']},
#                             {'workclass = Private': [{'age <= 43': [{'native_countr = United-States': [{'fnlwgt <= 107306': ['>50K',
#                                     {'fnlwgt <= 108282': ['<=50K',
#                                       {'fnlwgt <= 214816': [{'race = Black': ['<=50K',
#                                           {'fnlwgt <= 197252': [{'fnlwgt <= 176138': [{'fnlwgt <= 175856': [{'fnlwgt <= 167482': [{'fnlwgt <= 166416': [{'hours_per_week <= 45': [{'age <= 36': ['<=50K',
#                                                         '>50K']},
#                                                       '>50K']},
#                                                     '<=50K']},
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               '>50K']},
#                                             {'hours_per_week <= 48': ['>50K',
#                                               '<=50K']}]}]},
#                                         {'fnlwgt <= 234807': ['>50K',
#                                           {'fnlwgt <= 237713': ['<=50K',
#                                             {'hours_per_week <= 45': [{'age <= 42': [{'age <= 39': [{'race = White': [{'fnlwgt <= 384150': [{'hours_per_week <= 43': ['>50K',
#                                                         '<=50K']},
#                                                       '<=50K']},
#                                                     '>50K']},
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               '>50K']}]}]}]}]}]},
#                                   {'age <= 38': [{'native_countr = Japan': ['>50K',
#                                       '<=50K']},
#                                     '>50K']}]},
#                                 {'fnlwgt <= 270194': [{'hours_per_week <= 75': [{'hours_per_week <= 32': ['<=50K',
#                                       '>50K']},
#                                     '<=50K']},
#                                   '>50K']}]},
#                               '>50K']}]},
#                           {'fnlwgt <= 213095': ['>50K', '<=50K']}]},
#                         '<=50K']},
#                       {'fnlwgt <= 119832': [{'education_num <= 12': [{'age <= 44': [{'fnlwgt <= 56651': ['<=50K',
#                               {'fnlwgt <= 115289': [{'workclass = Private': [{'fnlwgt <= 103323': [{'sex = Male': [{'occupation = Prof-specialty': ['>50K',
#                                         '<=50K']},
#                                       '>50K']},
#                                     '>50K']},
#                                   '<=50K']},
#                                 '<=50K']}]},
#                             {'occupation = Craft-repair': ['<=50K',
#                               {'race = White': [{'occupation = Tech-support': ['>50K',
#                                   {'age <= 45': ['>50K', '<=50K']}]},
#                                 '<=50K']}]}]},
#                           {'fnlwgt <= 118793': [{'occupation = Transport-moving': ['<=50K',
#                               {'age <= 39': [{'workclass = Private': ['>50K',
#                                   {'fnlwgt <= 85566': ['<=50K',
#                                     {'fnlwgt <= 108320': ['>50K',
#                                       '<=50K']}]}]},
#                                 {'capital_gain <= 3103': [{'relationship = Other-relative': ['<=50K',
#                                     {'occupation = Machine-op-inspct': ['<=50K',
#                                       {'hours_per_week <= 50': [{'hours_per_week <= 43': [{'fnlwgt <= 104813': ['>50K',
#                                             {'age <= 41': ['<=50K',
#                                               {'age <= 44': ['>50K',
#                                                 '<=50K']}]}]},
#                                           {'hours_per_week <= 48': ['>50K',
#                                             {'age <= 56': [{'fnlwgt <= 104651': [{'age <= 51': [{'occupation = Sales': ['>50K',
#                                                     {'fnlwgt <= 23157': ['>50K',
#                                                       {'age <= 42': ['<=50K',
#                                                         {'age <= 45': ['>50K',
#                                                           {'occupation = Protective-serv': ['>50K',
#                                                             {'fnlwgt <= 82797': ['<=50K',
#                                                               '>50K']}]}]}]}]}]},
#                                                   '<=50K']},
#                                                 '>50K']},
#                                               '>50K']}]}]},
#                                         '<=50K']}]}]},
#                                   '<=50K']}]}]},
#                             '<=50K']}]},
#                         {'occupation = Farming-fishing': ['<=50K',
#                           {'occupation = Handlers-cleaners': [{'fnlwgt <= 263439': [{'native_countr = United-States': ['<=50K',
#                                 '>50K']},
#                               '>50K']},
#                             {'capital_loss <= 1485': [{'fnlwgt <= 350103': [{'fnlwgt <= 349534': [{'native_countr = India': ['<=50K',
#                                     {'hours_per_week <= 50': [{'native_countr = Peru': ['<=50K',
#                                         {'native_countr = Mexico': ['<=50K',
#                                           {'age <= 69': [{'age <= 51': [{'occupation = Transport-moving': ['<=50K',
#                                                 {'race = Other': ['>50K',
#                                                   {'fnlwgt <= 285787': [{'fnlwgt <= 166220': ['>50K',
#                                                       {'fnlwgt <= 172538': ['>50K',
#                                                         {'native_countr = Columbia': ['<=50K',
#                                                           {'fnlwgt <= 172571': ['<=50K',
#                                                             {'occupation = Craft-repair': [{'race = White': [{'age <= 35': ['<=50K',
#                                                                   {'fnlwgt <= 256997': [{'age <= 43': [{'fnlwgt <= 186212': ['<=50K',
#                                                                         '>50K']},
#                                                                       '>50K']},
#                                                                     '>50K']}]},
#                                                                 '>50K']},
#                                                               '>50K']}]}]}]}]},
#                                                     '>50K']}]}]},
#                                               {'race = White': [{'age <= 61': ['>50K',
#                                                   {'hours_per_week <= 40': [{'occupation = Craft-repair': ['>50K',
#                                                       {'fnlwgt <= 143880': ['>50K',
#                                                         {'fnlwgt <= 181014': ['<=50K',
#                                                           {'age <= 64': ['<=50K',
#                                                             '>50K']}]}]}]},
#                                                     '>50K']}]},
#                                                 '<=50K']}]},
#                                             '<=50K']}]}]},
#                                       '>50K']}]},
#                                   '<=50K']},
#                                 '>50K']},
#                               '<=50K']}]}]}]}]},
#                     {'occupation = Adm-clerical': ['>50K',
#                       {'occupation = Machine-op-inspct': ['<=50K',
#                         {'age <= 61': [{'native_countr = United-States': [{'age <= 41': [{'fnlwgt <= 36556': ['>50K',
#                                 {'fnlwgt <= 65324': ['>50K',
#                                   {'hours_per_week <= 45': [{'age <= 39': [{'fnlwgt <= 242720': [{'fnlwgt <= 188576': [{'fnlwgt <= 186845': [{'occupation = Exec-managerial': ['>50K',
#                                               {'education_num <= 15': [{'fnlwgt <= 75826': ['<=50K',
#                                                   '>50K']},
#                                                 '<=50K']}]},
#                                             '<=50K']},
#                                           '>50K']},
#                                         {'fnlwgt <= 314310': [{'age <= 38': ['<=50K',
#                                             '>50K']},
#                                           '>50K']}]},
#                                       '>50K']},
#                                     '>50K']}]}]},
#                               {'education = Prof-school': ['>50K',
#                                 {'hours_per_week <= 57': [{'age <= 58': ['>50K',
#                                     {'fnlwgt <= 140478': ['>50K',
#                                       {'hours_per_week <= 50': [{'capital_gain <= 3103': [{'occupation = Exec-managerial': ['>50K',
#                                             {'workclass = Local-gov': ['>50K',
#                                               {'education_num <= 14': ['<=50K',
#                                                 '>50K']}]}]},
#                                           '<=50K']},
#                                         '<=50K']}]}]},
#                                   '>50K']}]}]},
#                             '>50K']},
#                           '>50K']}]}]}]}]},
#                 '<=50K']}]}]}]},
#         {'capital_loss <= 1977': ['>50K',
#           {'capital_loss <= 2163': ['<=50K', '>50K']}]}]},
#       '>50K']}]},
#   {'capital_gain <= 6849': [{'education_num <= 12': [{'age <= 33': ['<=50K',
#         {'hours_per_week <= 41': [{'occupation = Other-service': ['<=50K',
#             {'capital_loss <= 2206': [{'relationship = Not-in-family': [{'sex = Male': [{'capital_gain <= 4650': [{'education_num <= 9': [{'workclass = State-gov': ['<=50K',
#                         {'occupation = Adm-clerical': [{'native_countr = Italy': ['>50K',
#                             {'age <= 34': ['>50K',
#                               {'fnlwgt <= 235693': [{'fnlwgt <= 220585': ['<=50K',
#                                   '>50K']},
#                                 '<=50K']}]}]},
#                           '<=50K']}]},
#                       {'marital_status = Separated': ['<=50K',
#                         {'native_countr = United-States': [{'race = Black': ['<=50K',
#                             {'age <= 45': [{'hours_per_week <= 12': ['>50K',
#                                 {'age <= 42': [{'workclass = Federal-gov': [{'age <= 37': ['<=50K',
#                                       '>50K']},
#                                     '<=50K']},
#                                   '<=50K']}]},
#                               '<=50K']}]},
#                           '<=50K']}]}]},
#                     {'capital_gain <= 4787': ['>50K', '<=50K']}]},
#                   '<=50K']},
#                 '<=50K']},
#               {'race = White': [{'occupation = Prof-specialty': ['<=50K',
#                   {'education = HS-grad': ['<=50K', '>50K']}]},
#                 '<=50K']}]}]},
#           {'capital_loss <= 2339': ['<=50K', '>50K']}]}]},
#       {'age <= 27': ['<=50K',
#         {'hours_per_week <= 42': [{'capital_loss <= 2339': [{'age <= 34': [{'hours_per_week <= 39': ['<=50K',
#                 {'education_num <= 14': [{'relationship = Wife': ['>50K',
#                     {'race = Black': ['<=50K',
#                       {'workclass = Local-gov': ['<=50K',
#                         {'relationship = Unmarried': ['<=50K',
#                           {'age <= 32': [{'fnlwgt <= 31493': ['<=50K',
#                               {'capital_loss <= 1408': ['<=50K',
#                                 {'capital_loss <= 1564': ['>50K',
#                                   '<=50K']}]}]},
#                             '<=50K']}]}]}]}]},
#                   {'age <= 31': ['<=50K',
#                     {'sex = Male': ['>50K', '<=50K']}]}]}]},
#               '<=50K']},
#             '>50K']},
#           {'capital_loss <= 2339': [{'education_num <= 14': [{'occupation = Exec-managerial': [{'marital_status = Never-married': ['<=50K',
#                   {'workclass = Self-emp-not-inc': [{'fnlwgt <= 275445': ['<=50K',
#                       '>50K']},
#                     {'fnlwgt <= 193755': [{'fnlwgt <= 171242': [{'workclass = Federal-gov': ['>50K',
#                           {'fnlwgt <= 168906': [{'age <= 59': [{'age <= 53': [{'hours_per_week <= 75': [{'marital_status = Married-spouse-absent': ['>50K',
#                                     '<=50K']},
#                                   '>50K']},
#                                 '>50K']},
#                               '<=50K']},
#                             '<=50K']}]},
#                         '>50K']},
#                       {'fnlwgt <= 262777': [{'age <= 41': ['<=50K',
#                           {'hours_per_week <= 48': ['<=50K',
#                             {'hours_per_week <= 50': [{'fnlwgt <= 200949': ['<=50K',
#                                 '>50K']},
#                               '>50K']}]}]},
#                         {'workclass = Self-emp-inc': ['<=50K',
#                           {'fnlwgt <= 304512': ['>50K',
#                             {'fnlwgt <= 354923': ['<=50K',
#                               '>50K']}]}]}]}]}]}]},
#                 {'marital_status = Married-AF-spouse': ['>50K',
#                   {'fnlwgt <= 148437': ['<=50K',
#                     {'age <= 61': [{'age <= 44': [{'relationship = Own-child': ['<=50K',
#                           {'workclass = Local-gov': ['<=50K',
#                             {'age <= 43': [{'occupation = Adm-clerical': ['<=50K',
#                                 {'native_countr = United-States': [{'workclass = State-gov': ['<=50K',
#                                     {'fnlwgt <= 279173': [{'race = Black': ['<=50K',
#                                         {'race = White': [{'fnlwgt <= 229732': [{'capital_gain <= 0': [{'age <= 41': [{'hours_per_week <= 52': [{'fnlwgt <= 204984': [{'fnlwgt <= 180572': [{'fnlwgt <= 179641': [{'marital_status = Never-married': [{'occupation = Sales': ['>50K',
#                                                             '<=50K']},
#                                                           '<=50K']},
#                                                         '>50K']},
#                                                       '<=50K']},
#                                                     {'fnlwgt <= 207335': ['>50K',
#                                                       '<=50K']}]},
#                                                   {'marital_status = Divorced': ['<=50K',
#                                                     '>50K']}]},
#                                                 '<=50K']},
#                                               '<=50K']},
#                                             '<=50K']},
#                                           '>50K']}]},
#                                       '<=50K']}]},
#                                   '<=50K']}]},
#                               '<=50K']}]}]},
#                         {'race = White': [{'fnlwgt <= 343333': [{'occupation = Sales': ['>50K',
#                               {'fnlwgt <= 285730': [{'fnlwgt <= 171807': [{'hours_per_week <= 56': ['>50K',
#                                     '<=50K']},
#                                   {'sex = Male': ['<=50K',
#                                     {'age <= 58': ['<=50K', '>50K']}]}]},
#                                 {'occupation = Adm-clerical': ['>50K',
#                                   '<=50K']}]}]},
#                             '<=50K']},
#                           '>50K']}]},
#                       '<=50K']}]}]}]},
#               {'age <= 32': ['<=50K',
#                 {'age <= 58': [{'workclass = Self-emp-not-inc': ['>50K',
#                     {'hours_per_week <= 70': [{'relationship = Other-relative': ['<=50K',
#                         {'fnlwgt <= 37869': ['<=50K', '>50K']}]},
#                       '<=50K']}]},
#                   '<=50K']}]}]},
#             '>50K']}]}]}]},
#     {'capital_gain <= 7978': [{'capital_gain <= 7430': ['>50K',
#         {'workclass = Local-gov': ['>50K', '<=50K']}]},
#       {'age <= 19': ['<=50K', '>50K']}]}]}]}

# %%
count_nodes(pruned_tree)
# Out:
# 1557

# %%
count_depth(pruned_tree)
# Out:
# 80

# %%
def acc_on_sets(tree,train_df,test_df):
    accuracy_train = calculate_accuracy(train_df,tree)
    accuracy_test = calculate_accuracy(test_df,tree)

    print("Training Set Accuracy:",accuracy_train)
    print("Test Set Accuracy:",accuracy_test)

# %%
acc_on_sets(tree , df_train, df_test)#combined tree
# Out:
# Training Set Accuracy: 0.9706942916513873
# Test Set Accuracy: 0.8236753939694751

# %%
acc_on_sets(pruned_tree,df_train,df_test)
# Out:
# Training Set Accuracy: 0.8990343478792324
# Test Set Accuracy: 0.8733713860280432
