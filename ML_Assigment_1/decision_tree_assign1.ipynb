# %% [markdown]
# Import Statements

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import random 
from pprint import pprint

# %% [markdown]
# Load and Prepare Data

# %%
df = pd.read_csv("census-income.data.csv") #Loading Census data

#Handling Missing Values

#df.info()

#Missing values in census-income.data.csv

#So we move on...

df1 = pd.read_csv("census-income.test.csv")

# %%
def determine_type_of_feature(df):
    feature_types = []
    n_unique_values_threshold = 15

    for column in df.columns:
        unique_values = df[column].unique()
        example_value = unique_values[0]

        if (isinstance(example_value, str)) or (len(unique_values) <= n_unique_values_threshold):
            feature_types.append("Discrete")
        else:
            feature_types.append("Continuous")
    
    return feature_types

# %%
global FEATURE_TYPES
FEATURE_TYPES = determine_type_of_feature(df)

# %%
#Checking which all columns have missing values
def missing_values(df):
    c=0
    for i in df.columns:
        x,count_missing = np.unique(df[i].eq('?'),return_counts=True)
        if len(x)==2:
            print(i,"-",FEATURE_TYPES[c],"-",count_missing[1])
        # elif len(x)==1 and x[0] == False:
        #     print(i,"-",FEATURE_TYPES[c],"- 0",)
        c+=1

# %%
missing_values(df)
# Out:
# workclass - Discrete - 1836
# occupation - Discrete - 1843
# native_countr - Discrete - 583

# %%
missing_values(df1)
# Out:
# workclass - Discrete - 963
# occupation - Discrete - 966
# native_countr - Discrete - 274

# %%
#Since all columns are having the discrete value. We replace it with the missing values with the modes, i.e. the highest appearing value
mode_workclass = df.workclass.mode()[0]
mode_occupation = df.occupation.mode()[0]
mode_native_countr = df.native_countr.mode()[0]

#Filling the train and test data with the modes of missing values as they are discrete
df.workclass = df.workclass.replace('?', mode_workclass)
df.occupation = df.occupation.replace('?', mode_occupation)
df.native_countr = df.native_countr.replace('?', mode_native_countr)
missing_values(df)#No missing values

# %%
#Similarly for the other test data
#Since all columns are having the discrete value. We replace it with the missing values with the modes, i.e. the highest appearing value
mode_workclass = df1.workclass.mode()[0]
mode_occupation = df1.occupation.mode()[0]
mode_native_countr = df1.native_countr.mode()[0]

#Filling the train and test data with the modes of missing values as they are discrete
df1.workclass = df1.workclass.replace('?', mode_workclass)
df1.occupation = df1.occupation.replace('?', mode_occupation)
df1.native_countr = df1.native_countr.replace('?', mode_native_countr)

missing_values(df1)

#No missing values

# %% [markdown]
# Random Splitting Of Data

# %%
def train_test_split(df,test_size):
    #checks whether the test_size is a proportion of the total number of samples
    if isinstance(test_size,float): 
        test_size = round(test_size*len(df))

    #store random samples in the test and training data
    indices = df.index.tolist()
    test_indices = random.sample(population=indices, k = test_size)

    #random data points from sample sent to test and training data
    test_df = df.loc[test_indices]
    train_df = df.drop(test_indices)

    return train_df , test_df

# %% [markdown]
# Data Pure?

# %%
def check_purity(data):
    label_column = data[:,-1]
    unique_classes = np.unique(label_column)

    if len(unique_classes) ==  1:
        return True    
    else:
        return False

# %% [markdown]
# Classify Data

# %%
def classify_data(data): 
    label_column = data[:,-1]
    unique_classes , counts_unique_classes = np.unique(label_column,return_counts = True)

    index = counts_unique_classes.argmax()
    classification = unique_classes[index]
    return classification

# %%
def get_potential_splits(data):
    potential_splits = {}
    rows , n_columns = data.shape

    for column_index in range(n_columns-1):
        values = data[:,column_index]
        unique_values = np.unique(values)
        
        
        potential_splits[column_index] = unique_values
            
    return potential_splits

# %%
# potential_splits = get_potential_splits(train_df.values)

# sns.lmplot(data = train_df, x = "petal_width", y = "petal_length",hue = "label", fit_reg = False,height=6,aspect = 1.5)

# # plt.vlines(x = potential_splits[3], ymin = 1, ymax =7)
# # plt.hlines(y=potential_splits[2],xmin=0,xmax =2.5)

# %% [markdown]
# Split Data

# %%
def split_data(data, split_column,split_value):
    split_column_values = data[:,split_column]

    type_of_feature = FEATURE_TYPES[split_column]
    
    if type_of_feature == "Continuous":
        data_below = data[split_column_values <= split_value]
        data_above = data[split_column_values > split_value]
    
    else:
        data_below = data[split_column_values == split_value]
        data_above = data[split_column_values != split_value]

    return data_below , data_above

# %%
# split_value = 0.8
# plotting_df = pd.DataFrame(data,columns = df.columns)
# sns.lmplot(data = plotting_df, x = "petal_width", y = "petal_length", fit_reg=False)
# plt.vlines(x = split_value,ymin = 1, ymax =7)

# %%
def calculate_entropy(data):
    label_column = data[:,-1]
    rows , counts = np.unique(label_column , return_counts =True)

    probabilities = counts / counts.sum()
    entropy = np.sum(probabilities*-np.log2(probabilities))

    return entropy

# %%
def calculate_overall_entropy(data_below, data_above):
    
    n_data_points = len(data_below) + len(data_above)

    p_data_below = len(data_below) / n_data_points
    p_data_above = len(data_above) / n_data_points

    overall_entropy = (p_data_below*calculate_entropy(data_below) + p_data_above*calculate_entropy(data_above))

    return overall_entropy

# %%
def determine_best_splits(data, potential_splits):

    overall_entropy = 999
    
    for column_index in potential_splits:
        # print(COLUMN_HEADERS[column_index],"-",len(np.unique(data[:, column_index])))
        for value in potential_splits[column_index]:
            
            data_below, data_above = split_data(data,split_column = column_index,split_value = value)
            current_overall_entropy = calculate_overall_entropy(data_below, data_above)
            
            if current_overall_entropy <= overall_entropy:
                overall_entropy = current_overall_entropy
                best_split_column = column_index
                best_split_value = value
    
    return best_split_column, best_split_value

# %% [markdown]
# Determine Whether Column is Discrete or Continuous

# %%
def decision_tree_algorithm(df , counter =0, min_samples=5, max_depth = 5):
    # print(counter)
    #Data Preparation
    if counter == 0:
        global COLUMN_HEADERS 
        global FEATURE_TYPES 
        COLUMN_HEADERS = df.columns
        FEATURE_TYPES = determine_type_of_feature(df)
        data = df.values
    else:
        data = df

    #Base Case 
    if (check_purity(data)) or (len(data) < min_samples) or (counter == max_depth):
        classification = classify_data(data)
        return classification 
    
    #Recursive case
    else:
        counter = counter + 1
        
        #helper functions
        potential_splits = get_potential_splits(data)        
        split_column,split_value = determine_best_splits(data,potential_splits)
        data_below,data_above = split_data(data,split_column,split_value)

        #checking for empty data

        if len(data_below) == 0 or len(data_above) == 0:
            classification = classify_data(data)
            return classification

        #instantiating the sub-trees
        feature_name = COLUMN_HEADERS[split_column]
        type_of_feature = FEATURE_TYPES[split_column]
        if type_of_feature == "Continuous":
            question = "{} <= {}".format(feature_name,split_value)

        else:
            question = "{} = {}".format(feature_name,split_value)

        sub_tree = {question:[]}

        #find answers (here recursion is used)
        yes_answer = decision_tree_algorithm(data_below, counter, min_samples , max_depth)
        no_answer = decision_tree_algorithm(data_above, counter, min_samples , max_depth)

        if yes_answer == no_answer:
            sub_tree = yes_answer
        else:
            sub_tree[question].append(yes_answer)
            sub_tree[question].append(no_answer)

        return sub_tree

# %%
def classify_example(example,tree):
    question = list(tree.keys())[0]
    feature_name , comparison_operator, value = question.split()

    #Asking the question to the example
    if comparison_operator == "<=":

        if example[feature_name] <= float(value):
            answer = tree[question][0]
        else:
            answer = tree[question][1]

    else:
        if str(example[feature_name]) == value:
            answer = tree[question][0]
        else:
            answer = tree[question][1]
    #base Case
    if not isinstance(answer,dict):
        return answer

    #recursive part
    else:
        remaining_tree = answer
        return classify_example(example,remaining_tree)

# %%
def calculate_accuracy(df,tree):

    df["Classification"] = df.apply(classify_example,axis=1,args = (tree,))
    df["Classification_Correct"] = df.Classification == df.label

    accuracy = df.Classification_Correct.mean()

    return accuracy

# %%
def make_predictions(df, tree):
    
    if len(df) != 0:
        predictions = df.apply(classify_example, args=(tree,), axis=1)
    else:
        # "df.apply()"" with empty dataframe returns an empty dataframe,
        # but "predictions" should be a series instead
        predictions = pd.Series()
        
    return predictions

# %%
def filter_df(df,question):
    feature,comparison_operator,value = question.split()

    if (comparison_operator) == "<=":
        df_yes = df[df[feature]<= float(value)]
        df_no = df[df[feature] > float(value)]
    
    else:
        df_yes = df[df[feature].astype(str) == value]
        df_no = df[df[feature].astype(str) != value]
        

    return df_yes,df_no

# %%
def pruning_result(tree, df_train, df_val):
    leaf = df_train.label.value_counts().index[0]
    errors_leaf = sum(df_val.label != leaf) #here we can find the accuracy also :D
    errors_decision_node = sum(df_val.label != make_predictions(df_val,tree))

    if errors_leaf <= errors_decision_node:
            return leaf
    else:
            return tree

# %%
def post_pruning(tree , df_train , df_val):
    question = list(tree.keys())[0]
    yes_answer , no_answer = tree[question]

    #base case
    if not isinstance(yes_answer,dict) and not isinstance(no_answer,dict):
        return pruning_result(tree , df_train , df_val)
    
    else: #Recursive case
        df_train_yes, df_train_no = filter_df(df_train , question)
        df_val_yes, df_val_no = filter_df(df_val , question)

        if isinstance(yes_answer,dict):
            yes_answer = post_pruning(yes_answer,df_train_yes,df_val_yes)

        if isinstance(no_answer,dict):
            no_answer = post_pruning(no_answer,df_train_no,df_val_no)
    
    tree = {question : [yes_answer,no_answer]}

    return pruning_result(tree , df_train , df_val)

# %%
def count_nodes(tree):
    if isinstance(tree, dict):
        count = 1  # Start with 1 for the current node
        for value in tree.values():
            count += count_nodes(value)  # Recursively count nodes in child dictionaries
        return count
    elif isinstance(tree, list):
        count = 0
        for node in tree:
            count += count_nodes(node)  # Recursively count nodes in child dictionaries
        return count
    else:
        return 1  # Reached a leaf node

# %%
def count_depth(tree):
    if isinstance(tree, dict):
        if not tree:  # Base case: empty dictionary
            return 1
        else:
            return 1 + max(count_depth(value) for value in tree.values())
    elif isinstance(tree, list):
        if not tree:  # Base case: empty list
            return 1
        else:
            return 1 + max(count_depth(item) for item in tree)
    else:
        return 0  # Base case: leaf node or invalid input

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_countr   32561 non-null  object
#  14  label           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
random.seed(0)
train_df = df
valid_df,test_df = train_test_split(df1,test_size=0.5)

# %%
tree = decision_tree_algorithm(train_df,max_depth = 40)

# %%
pprint(tree,width=50)
# Out:
# {'marital_status = Married-civ-spouse': [{'education_num <= 12': [{'capital_gain <= 5013': [{'education_num <= 8': [{'age <= 36': [{'hours_per_week <= 48': [{'occupation = Tech-support': [{'fnlwgt <= 195516': ['<=50K',
#                                                                                                                                                                                                                   '>50K']},
#                                                                                                                                                                                             {'native_countr = Trinadad&Tobago': ['>50K',
#                                                                                                                                                                                                                                  {'capital_loss <= 1651': [{'fnlwgt <= 180284': [{'fnlwgt <= 179666': [{'education = 11th': ['<=50K',
#                                                                                                                                                                                                                                                                                                                              {'native_countr = Laos': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                        {'fnlwgt <= 132879': [{'occupation = Machine-op-inspct': [{'education = 7th-8th': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                           '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                  '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                              {'fnlwgt <= 133136': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                    {'occupation = Craft-repair': [{'hours_per_week <= 43': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                             '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                   '<=50K']}]}]}]}]},
#                                                                                                                                                                                                                                                                                                        '>50K']},
#                                                                                                                                                                                                                                                                                  {'occupation = Adm-clerical': ['<=50K',
#                                                                                                                                                                                                                                                                                                                 {'occupation = Sales': [{'education_num <= 7': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                 '>50K']},
#                                                                                                                                                                                                                                                                                                                                         '<=50K']}]}]},
#                                                                                                                                                                                                                                                            {'capital_loss <= 1902': ['>50K',
#                                                                                                                                                                                                                                                                                      '<=50K']}]}]}]},
#                                                                                                                                                              {'relationship = Not-in-family': ['>50K',
#                                                                                                                                                                                                {'hours_per_week <= 50': [{'native_countr = United-States': [{'relationship = Own-child': ['>50K',
#                                                                                                                                                                                                                                                                                           {'workclass = Self-emp-inc': ['>50K',
#                                                                                                                                                                                                                                                                                                                         {'age <= 33': [{'fnlwgt <= 249249': [{'fnlwgt <= 217460': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                    '>50K']},
#                                                                                                                                                                                                                                                                                                                                                              '<=50K']},
#                                                                                                                                                                                                                                                                                                                                        '<=50K']}]}]},
#                                                                                                                                                                                                                                                             '>50K']},
#                                                                                                                                                                                                                          {'fnlwgt <= 29312': ['>50K',
#                                                                                                                                                                                                                                               '<=50K']}]}]}]},
#                                                                                                                                    {'age <= 66': [{'capital_loss <= 1672': [{'education_num <= 5': [{'hours_per_week <= 49': [{'workclass = Self-emp-inc': [{'fnlwgt <= 125417': ['>50K',
#                                                                                                                                                                                                                                                                                   {'education = 5th-6th': ['>50K',
#                                                                                                                                                                                                                                                                                                            '<=50K']}]},
#                                                                                                                                                                                                                                                             {'occupation = Exec-managerial': [{'fnlwgt <= 103153': ['<=50K',
#                                                                                                                                                                                                                                                                                                                     {'fnlwgt <= 278114': ['>50K',
#                                                                                                                                                                                                                                                                                                                                           '<=50K']}]},
#                                                                                                                                                                                                                                                                                               {'workclass = Self-emp-not-inc': [{'native_countr = United-States': [{'age <= 40': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                   {'age <= 55': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                  {'age <= 58': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                 {'occupation = Craft-repair': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                {'education_num <= 4': [{'occupation = Farming-fishing': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'fnlwgt <= 127805': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                '<=50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        '>50K']}]}]}]}]},
#                                                                                                                                                                                                                                                                                                                                                                    '<=50K']},
#                                                                                                                                                                                                                                                                                                                                 {'fnlwgt <= 30673': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                      {'native_countr = Yugoslavia': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                      {'fnlwgt <= 390856': [{'native_countr = Vietnam': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                         {'native_countr = Haiti': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {'occupation = Sales': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            {'occupation = Machine-op-inspct': [{'age <= 45': [{'fnlwgt <= 234652': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'age <= 41': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    '<=50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {'fnlwgt <= 136107': [{'fnlwgt <= 130714': [{'education = 5th-6th': [{'fnlwgt <= 53833': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      '<=50K']}]}]}]}]},
#                                                                                                                                                                                                                                                                                                                                                                                                            '<=50K']}]}]}]}]}]},
#                                                                                                                                                                                                                               {'hours_per_week <= 80': [{'occupation = Other-service': ['<=50K',
#                                                                                                                                                                                                                                                                                         {'fnlwgt <= 177995': [{'fnlwgt <= 168539': [{'age <= 38': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                    {'fnlwgt <= 110015': [{'occupation = Craft-repair': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                         '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                          {'fnlwgt <= 155489': [{'workclass = Self-emp-inc': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                              {'occupation = Sales': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'occupation = Exec-managerial': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'hours_per_week <= 55': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  '>50K']}]}]}]},
#                                                                                                                                                                                                                                                                                                                                                                                                '<=50K']}]}]},
#                                                                                                                                                                                                                                                                                                                                     '>50K']},
#                                                                                                                                                                                                                                                                                                               {'education_num <= 3': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                       {'age <= 44': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                      {'capital_gain <= 0': [{'fnlwgt <= 259532': [{'occupation = Handlers-cleaners': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                       {'age <= 51': [{'occupation = Craft-repair': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      '<=50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                   '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                             '<=50K']}]}]}]}]},
#                                                                                                                                                                                                                                                         '<=50K']}]},
#                                                                                                                                                                                                     {'fnlwgt <= 364913': [{'fnlwgt <= 198316': [{'hours_per_week <= 56': [{'fnlwgt <= 197286': [{'hours_per_week <= 20': ['<=50K',
#                                                                                                                                                                                                                                                                                                                           {'workclass = Local-gov': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                      {'capital_gain <= 4064': [{'age <= 43': [{'age <= 41': [{'occupation = Transport-moving': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'capital_gain <= 2635': [{'age <= 39': [{'age <= 38': [{'occupation = Machine-op-inspct': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'hours_per_week <= 40': [{'occupation = Craft-repair': [{'education_num <= 7': [{'fnlwgt <= 112271': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       '<=50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'education_num <= 7': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  '>50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '>50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                              '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                               {'age <= 53': [{'fnlwgt <= 180446': [{'native_countr = Cambodia': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {'age <= 44': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'hours_per_week <= 45': [{'fnlwgt <= 168598': [{'occupation = Machine-op-inspct': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'capital_gain <= 0': [{'age <= 45': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'occupation = Exec-managerial': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'fnlwgt <= 153486': [{'fnlwgt <= 152810': [{'age <= 52': [{'occupation = Farming-fishing': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'fnlwgt <= 128460': [{'fnlwgt <= 107373': [{'fnlwgt <= 61885': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'workclass = State-gov': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      '>50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                '>50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   '<=50K']}]}]},
# ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              '<=50K']}]}]}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   '<=50K']}]}]}]}]}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                        '<=50K']}]},
#                                                                                                                                                                                                                                                                                                                                                          '<=50K']}]}]},
#                                                                                                                                                                                                                                                                                       {'age <= 38': [{'fnlwgt <= 377283': ['>50K',
#                                                                                                                                                                                                                                                                                                                            '<=50K']},
#                                                                                                                                                                                                                                                                                                      '<=50K']}]}]}]},
#                                                                                                                                                                                                                           {'age <= 32': [{'native_countr = United-States': [{'marital_status = Never-married': [{'fnlwgt <= 76714': [{'fnlwgt <= 71067': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                           '>50K']},
#                                                                                                                                                                                                                                                                                                                                      '<=50K']},
#                                                                                                                                                                                                                                                                                                                 {'relationship = Not-in-family': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                   '<=50K']}]},
#                                                                                                                                                                                                                                                                             {'fnlwgt <= 196025': ['<=50K',
#                                                                                                                                                                                                                                                                                                   '>50K']}]},
#                                                                                                                                                                                                                                          {'hours_per_week <= 80': [{'workclass = Federal-gov': ['>50K',
#                                                                                                                                                                                                                                                                                                 {'age <= 35': [{'fnlwgt <= 44464': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                     '>50K']},
#                                                                                                                                                                                                                                                                                                                {'hours_per_week <= 50': [{'age <= 53': [{'hours_per_week <= 48': [{'marital_status = Never-married': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                       '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                   {'relationship = Not-in-family': [{'occupation = Prof-specialty': [{'marital_status = Divorced': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'sex = Male': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '>50K']}]},
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                     '>50K']}]},
#                                                                                                                                                                                                                                                                                                                                                         '<=50K']},
#                                                                                                                                                                                                                                                                                                                                          {'hours_per_week <= 55': ['>50K',
#                                                                                                                                                                                                                                                                                                                                                                    {'marital_status = Never-married': [{'fnlwgt <= 186410': [{'fnlwgt <= 99359': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                   '>50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                                              '<=50K']},
#                                                                                                                                                                                                                                                                                                                                                                                                        {'occupation = Sales': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                {'relationship = Unmarried': ['<=50K',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                              '>50K']}]}]}]}]}]}]},
#                                                                                                                                                                                                                                                                    '<=50K']}]}]}]},
#                                                                                                                                                                '>50K']}]}]}]},
#                                                                    {'age <= 20': ['<=50K',
#                                                                                   {'capital_gain <= 7978': [{'education_num <= 10': [{'workclass = Private': ['<=50K',
#                                                                                                                                                               '>50K']},
#                                                                                                                                      '>50K']},
#                                                                                                             {'capital_gain <= 27828': ['>50K',
#                                                                                                                                        {'capital_gain <= 34095': ['<=50K',
#                                                                                                                                                                   '>50K']}]}]}]}]}]}

# %%
depth_count = count_depth(tree)
node_count = count_nodes(tree)
print(node_count)
print(depth_count)
# Out:
# 6613
# 80

# %%
valid_df.iloc[1]
# Out:
# age                          34
# workclass               Private
# fnlwgt                   198693
# education                  10th
# education_num                 6
# marital_status    Never-married
# occupation        Other-service
# relationship      Not-in-family
# race                      White
# sex                        Male
# capital_gain                  0
# capital_loss                  0
# hours_per_week               30
# native_countr     United-States
# label                    <=50K.
# Name: 5, dtype: object

# %%
valid_df['label'] = valid_df['label'].str.replace('.', '')
test_df['label'] = test_df['label'].str.replace('.', '')

# %%
example = valid_df.iloc[1]
example
# Out:
# age                          34
# workclass               Private
# fnlwgt                   198693
# education                  10th
# education_num                 6
# marital_status    Never-married
# occupation        Other-service
# relationship      Not-in-family
# race                      White
# sex                        Male
# capital_gain                  0
# capital_loss                  0
# hours_per_week               30
# native_countr     United-States
# label                     <=50K
# Name: 5, dtype: object

# %%
accuracy_train = calculate_accuracy(train_df,tree)
accuracy_val = calculate_accuracy(valid_df,tree)
accuracy_test = calculate_accuracy(test_df,tree)
print("Training Set Accuracy:",accuracy_train)
print("Validation Set Accuracy:",accuracy_val)
print("Test Set Accuracy:",accuracy_test)
# Out:
# Training Set Accuracy: 0.9734959000030712
# Validation Set Accuracy: 0.8292593047537158
# Test Set Accuracy: 0.8164619164619165

# %%
pruned_tree = post_pruning(tree,train_df,valid_df)

# %%
print(count_nodes(pruned_tree))
print(count_depth(pruned_tree))
# Out:
# 1373
# 80

# %%
pruned_tree
# Out:
# {'marital_status = Married-civ-spouse': [{'education_num <= 12': [{'capital_gain <= 5013': [{'education_num <= 8': [{'age <= 36': ['<=50K',
#           {'age <= 66': [{'capital_loss <= 1672': [{'education_num <= 5': [{'hours_per_week <= 49': ['<=50K',
#                   {'hours_per_week <= 80': [{'occupation = Other-service': ['<=50K',
#                       {'fnlwgt <= 177995': ['<=50K',
#                         {'education_num <= 3': ['<=50K',
#                           {'age <= 44': ['<=50K',
#                             {'capital_gain <= 0': [{'fnlwgt <= 259532': [{'occupation = Handlers-cleaners': ['>50K',
#                                   {'age <= 51': ['>50K', '<=50K']}]},
#                                 '>50K']},
#                               '<=50K']}]}]}]}]},
#                     '<=50K']}]},
#                 {'fnlwgt <= 364913': ['<=50K',
#                   {'fnlwgt <= 431513': [{'fnlwgt <= 411652': ['<=50K',
#                       '>50K']},
#                     '<=50K']}]}]},
#               {'capital_loss <= 1977': ['>50K', '<=50K']}]},
#             '<=50K']}]},
#         {'age <= 35': [{'age <= 24': [{'hours_per_week <= 45': [{'fnlwgt <= 515797': [{'age <= 22': ['<=50K',
#                   {'capital_gain <= 3942': [{'fnlwgt <= 231473': ['<=50K',
#                       {'fnlwgt <= 241523': [{'hours_per_week <= 38': ['<=50K',
#                           '>50K']},
#                         '<=50K']}]},
#                     '>50K']}]},
#                 '>50K']},
#               '<=50K']},
#             {'capital_loss <= 1740': [{'education_num <= 9': [{'hours_per_week <= 51': [{'race = Black': ['<=50K',
#                     {'age <= 28': [{'hours_per_week <= 43': [{'fnlwgt <= 180553': ['<=50K',
#                           {'occupation = Protective-serv': ['<=50K',
#                             {'age <= 25': ['<=50K',
#                               {'workclass = Private': [{'relationship = Husband': [{'fnlwgt <= 375313': [{'fnlwgt <= 233777': [{'fnlwgt <= 224849': ['<=50K',
#                                         '>50K']},
#                                       '<=50K']},
#                                     '<=50K']},
#                                   '<=50K']},
#                                 '<=50K']}]}]}]},
#                         '<=50K']},
#                       {'fnlwgt <= 87310': ['<=50K',
#                         {'relationship = Wife': ['<=50K',
#                           {'hours_per_week <= 38': ['<=50K',
#                             {'capital_gain <= 3103': [{'capital_gain <= 2885': [{'native_countr = Cuba': ['>50K',
#                                   {'fnlwgt <= 95299': [{'fnlwgt <= 93930': ['<=50K',
#                                       '>50K']},
#                                     {'occupation = Transport-moving': ['<=50K',
#                                       {'occupation = Farming-fishing': ['<=50K',
#                                         {'workclass = Private': [{'native_countr = Yugoslavia': ['>50K',
#                                             {'fnlwgt <= 460408': [{'fnlwgt <= 452924': [{'occupation = Prof-specialty': ['<=50K',
#                                                   {'race = White': [{'fnlwgt <= 112264': ['<=50K',
#                                                       {'fnlwgt <= 113364': ['>50K',
#                                                         {'fnlwgt <= 122116': ['<=50K',
#                                                           {'fnlwgt <= 123270': ['>50K',
#                                                             {'fnlwgt <= 164190': [{'hours_per_week <= 42': ['<=50K',
#                                                                 '>50K']},
#                                                               '<=50K']}]}]}]}]},
#                                                     '<=50K']}]},
#                                                 '>50K']},
#                                               '<=50K']}]},
#                                           '<=50K']}]}]}]}]},
#                                 '>50K']},
#                               '<=50K']}]}]}]}]}]},
#                   '<=50K']},
#                 {'fnlwgt <= 165930': [{'fnlwgt <= 27142': ['>50K',
#                     {'fnlwgt <= 83748': ['<=50K',
#                       {'fnlwgt <= 84154': ['>50K',
#                         {'capital_loss <= 1485': [{'occupation = Protective-serv': ['<=50K',
#                             {'occupation = Handlers-cleaners': ['<=50K',
#                               {'age <= 29': ['<=50K',
#                                 {'capital_gain <= 0': [{'occupation = Craft-repair': [{'fnlwgt <= 126501': ['<=50K',
#                                       {'fnlwgt <= 133770': ['>50K',
#                                         {'fnlwgt <= 154950': ['<=50K',
#                                           {'workclass = Private': [{'fnlwgt <= 160634': ['>50K',
#                                               '<=50K']},
#                                             '<=50K']}]}]}]},
#                                     '<=50K']},
#                                   '<=50K']}]}]}]},
#                           '<=50K']}]}]}]},
#                   {'age <= 30': [{'occupation = Tech-support': [{'relationship = Wife': ['<=50K',
#                         {'age <= 27': ['<=50K', '>50K']}]},
#                       {'hours_per_week <= 60': [{'hours_per_week <= 35': ['<=50K',
#                           {'fnlwgt <= 183151': ['<=50K',
#                             {'relationship = Wife': ['>50K',
#                               {'capital_gain <= 3103': [{'capital_gain <= 2829': ['<=50K',
#                                   '>50K']},
#                                 '<=50K']}]}]}]},
#                         '<=50K']}]},
#                     {'occupation = Exec-managerial': [{'workclass = Self-emp-not-inc': ['<=50K',
#                         {'sex = Male': [{'hours_per_week <= 58': [{'age <= 34': ['>50K',
#                               '<=50K']},
#                             '>50K']},
#                           '>50K']}]},
#                       {'occupation = Machine-op-inspct': ['<=50K',
#                         {'capital_loss <= 1485': [{'fnlwgt <= 226696': [{'hours_per_week <= 20': ['<=50K',
#                               {'capital_gain <= 3464': [{'hours_per_week <= 75': [{'hours_per_week <= 64': [{'fnlwgt <= 191628': [{'education_num <= 10': [{'occupation = Other-service': ['<=50K',
#                                           {'fnlwgt <= 189368': ['>50K',
#                                             '<=50K']}]},
#                                         '<=50K']},
#                                       {'occupation = Prof-specialty': ['>50K',
#                                         '<=50K']}]},
#                                     '<=50K']},
#                                   '>50K']},
#                                 '>50K']}]},
#                             '<=50K']},
#                           '<=50K']}]}]}]}]}]},
#               {'capital_loss <= 1977': ['>50K', '<=50K']}]}]},
#           {'capital_loss <= 1740': [{'hours_per_week <= 34': [{'relationship = Wife': [{'occupation = Exec-managerial': ['>50K',
#                   {'fnlwgt <= 60641': ['<=50K',
#                     {'occupation = Adm-clerical': [{'hours_per_week <= 5': ['<=50K',
#                         {'fnlwgt <= 178983': ['>50K', '<=50K']}]},
#                       {'fnlwgt <= 65738': ['>50K',
#                         {'education_num <= 10': ['<=50K',
#                           {'fnlwgt <= 338355': [{'fnlwgt <= 100881': ['>50K',
#                               {'occupation = Tech-support': ['>50K',
#                                 {'occupation = Prof-specialty': [{'workclass = Self-emp-not-inc': ['>50K',
#                                     '<=50K']},
#                                   '<=50K']}]}]},
#                             '>50K']}]}]}]}]}]},
#                 {'education_num <= 9': [{'workclass = Self-emp-inc': ['<=50K',
#                     {'age <= 65': [{'fnlwgt <= 214838': [{'occupation = Craft-repair': ['<=50K',
#                           {'occupation = Protective-serv': ['>50K',
#                             {'hours_per_week <= 24': ['<=50K',
#                               {'fnlwgt <= 200749': ['<=50K', '>50K']}]}]}]},
#                         '<=50K']},
#                       '<=50K']}]},
#                   {'occupation = Other-service': ['<=50K',
#                     {'hours_per_week <= 6': ['<=50K',
#                       {'hours_per_week <= 8': ['<=50K',
#                         {'age <= 36': ['>50K', '<=50K']}]}]}]}]}]},
#               {'education_num <= 9': [{'occupation = Other-service': ['<=50K',
#                   {'occupation = Farming-fishing': ['<=50K',
#                     {'capital_loss <= 1485': [{'workclass = Federal-gov': ['>50K',
#                         {'hours_per_week <= 41': [{'occupation = Exec-managerial': [{'workclass = Self-emp-not-inc': [{'age <= 39': ['<=50K',
#                                 {'fnlwgt <= 83411': ['>50K',
#                                   {'fnlwgt <= 126094': ['<=50K',
#                                     {'fnlwgt <= 166083': ['>50K',
#                                       '<=50K']}]}]}]},
#                               {'age <= 36': ['<=50K',
#                                 {'fnlwgt <= 64322': ['<=50K',
#                                   {'fnlwgt <= 99434': ['>50K',
#                                     {'race = White': [{'fnlwgt <= 405309': [{'fnlwgt <= 387068': [{'age <= 69': [{'age <= 65': [{'hours_per_week <= 36': ['>50K',
#                                                 {'fnlwgt <= 132222': ['<=50K',
#                                                   {'fnlwgt <= 254949': [{'fnlwgt <= 185099': [{'fnlwgt <= 180804': [{'fnlwgt <= 178771': [{'fnlwgt <= 134854': ['>50K',
#                                                             {'workclass = Private': ['>50K',
#                                                               '<=50K']}]},
#                                                           '>50K']},
#                                                         '<=50K']},
#                                                       '>50K']},
#                                                     {'fnlwgt <= 303510': ['<=50K',
#                                                       {'fnlwgt <= 316000': ['>50K',
#                                                         {'fnlwgt <= 338740': ['<=50K',
#                                                           '>50K']}]}]}]}]}]},
#                                               '<=50K']},
#                                             '>50K']},
#                                           '<=50K']},
#                                         '>50K']},
#                                       '>50K']}]}]}]}]},
#                             {'relationship = Wife': [{'race = Black': ['<=50K',
#                                 {'age <= 40': ['>50K',
#                                   {'capital_gain <= 0': [{'native_countr = Italy': ['>50K',
#                                       {'occupation = Craft-repair': ['>50K',
#                                         {'workclass = Private': [{'hours_per_week <= 38': ['<=50K',
#                                             {'fnlwgt <= 181652': ['<=50K',
#                                               '>50K']}]},
#                                           '>50K']}]}]},
#                                     '<=50K']}]}]},
#                               {'age <= 46': ['<=50K',
#                                 {'age <= 59': [{'fnlwgt <= 548361': [{'fnlwgt <= 400285': [{'age <= 58': [{'capital_gain <= 4386': [{'capital_gain <= 4064': [{'capital_gain <= 3103': [{'capital_gain <= 2829': [{'fnlwgt <= 119565': ['<=50K',
#                                                   {'fnlwgt <= 240629': [{'fnlwgt <= 209146': [{'fnlwgt <= 199067': ['<=50K',
#                                                         {'occupation = Handlers-cleaners': ['>50K',
#                                                           '<=50K']}]},
#                                                       '>50K']},
#                                                     '<=50K']}]},
#                                                 '>50K']},
#                                               '<=50K']},
#                                             '>50K']},
#                                           '<=50K']},
#                                         {'fnlwgt <= 229939': [{'fnlwgt <= 195820': [{'fnlwgt <= 179594': [{'fnlwgt <= 144071': ['>50K',
#                                                 '<=50K']},
#                                               '>50K']},
#                                             '<=50K']},
#                                           '>50K']}]},
#                                       '<=50K']},
#                                     '>50K']},
#                                   '<=50K']}]}]}]},
#                           {'workclass = Self-emp-not-inc': ['<=50K',
#                             {'fnlwgt <= 328466': [{'race = White': [{'capital_gain <= 3103': [{'capital_gain <= 2885': [{'relationship = Husband': [{'fnlwgt <= 86373': ['<=50K',
#                                         {'fnlwgt <= 243409': [{'fnlwgt <= 97741': [{'fnlwgt <= 91857': ['<=50K',
#                                               '>50K']},
#                                             {'age <= 42': [{'fnlwgt <= 100292': ['>50K',
#                                                 {'fnlwgt <= 116133': [{'fnlwgt <= 112283': [{'age <= 36': ['<=50K',
#                                                       '>50K']},
#                                                     '<=50K']},
#                                                   {'fnlwgt <= 120590': ['>50K',
#                                                     {'hours_per_week <= 44': [{'fnlwgt <= 216924': [{'fnlwgt <= 162164': ['<=50K',
#                                                           '>50K']},
#                                                         '<=50K']},
#                                                       {'age <= 37': ['>50K',
#                                                         {'hours_per_week <= 60': [{'occupation = Craft-repair': ['<=50K',
#                                                             {'fnlwgt <= 144032': ['<=50K',
#                                                               {'fnlwgt <= 165466': ['>50K',
#                                                                 {'occupation = Exec-managerial': ['>50K',
#                                                                   '<=50K']}]}]}]},
#                                                           '<=50K']}]}]}]}]}]},
#                                               {'fnlwgt <= 102193': ['<=50K',
#                                                 {'age <= 52': [{'fnlwgt <= 161438': [{'hours_per_week <= 43': ['>50K',
#                                                       {'age <= 47': [{'fnlwgt <= 156728': [{'fnlwgt <= 155489': [{'hours_per_week <= 58': [{'fnlwgt <= 144778': ['>50K',
#                                                                 '<=50K']},
#                                                               {'fnlwgt <= 148884': ['<=50K',
#                                                                 '>50K']}]},
#                                                             '<=50K']},
#                                                           '>50K']},
#                                                         '>50K']}]},
#                                                     {'fnlwgt <= 163678': ['<=50K',
#                                                       {'fnlwgt <= 165152': ['>50K',
#                                                         {'age <= 46': [{'occupation = Transport-moving': ['<=50K',
#                                                             '>50K']},
#                                                           {'age <= 51': [{'fnlwgt <= 180195': [{'fnlwgt <= 175246': [{'hours_per_week <= 50': ['>50K',
#                                                                   '<=50K']},
#                                                                 '<=50K']},
#                                                               {'fnlwgt <= 185846': ['>50K',
#                                                                 {'hours_per_week <= 56': [{'hours_per_week <= 48': ['<=50K',
#                                                                     '>50K']},
#                                                                   '<=50K']}]}]},
#                                                             '>50K']}]}]}]}]},
#                                                   {'fnlwgt <= 171924': [{'fnlwgt <= 165881': [{'age <= 63': [{'fnlwgt <= 161964': ['<=50K',
#                                                           '>50K']},
#                                                         '<=50K']},
#                                                       '<=50K']},
#                                                     {'occupation = Machine-op-inspct': ['<=50K',
#                                                       '>50K']}]}]}]}]}]},
#                                           {'hours_per_week <= 48': ['<=50K',
#                                             {'fnlwgt <= 256861': ['<=50K',
#                                               '>50K']}]}]}]},
#                                       '<=50K']},
#                                     '>50K']},
#                                   '<=50K']},
#                                 '<=50K']},
#                               {'occupation = Craft-repair': [{'hours_per_week <= 44': ['>50K',
#                                   '<=50K']},
#                                 {'age <= 51': ['>50K', '<=50K']}]}]}]}]}]},
#                       '<=50K']}]}]},
#                 {'workclass = Self-emp-not-inc': [{'occupation = Farming-fishing': [{'education_num <= 10': ['<=50K',
#                       {'fnlwgt <= 40666': ['<=50K',
#                         {'fnlwgt <= 170866': [{'hours_per_week <= 40': ['<=50K',
#                             {'capital_gain <= 0': ['>50K', '<=50K']}]},
#                           '<=50K']}]}]},
#                     {'fnlwgt <= 349910': ['<=50K',
#                       {'occupation = Sales': ['>50K',
#                         {'hours_per_week <= 40': ['>50K', '<=50K']}]}]}]},
#                   {'occupation = Exec-managerial': [{'capital_loss <= 1485': [{'hours_per_week <= 40': [{'capital_gain <= 0': [{'relationship = Husband': ['>50K',
#                             {'native_countr = Trinadad&Tobago': ['<=50K',
#                               {'fnlwgt <= 181413': [{'fnlwgt <= 170846': [{'hours_per_week <= 37': ['<=50K',
#                                     '>50K']},
#                                   '<=50K']},
#                                 '>50K']}]}]},
#                           '<=50K']},
#                         '>50K']},
#                       '<=50K']},
#                     {'occupation = Handlers-cleaners': ['<=50K',
#                       {'occupation = Other-service': ['<=50K',
#                         {'fnlwgt <= 154668': [{'occupation = Transport-moving': ['<=50K',
#                             {'workclass = Self-emp-inc': [{'hours_per_week <= 58': [{'education_num <= 10': [{'age <= 55': [{'fnlwgt <= 54953': [{'fnlwgt <= 49069': ['>50K',
#                                         '<=50K']},
#                                       '>50K']},
#                                     '<=50K']},
#                                   '>50K']},
#                                 '<=50K']},
#                               {'fnlwgt <= 154076': [{'fnlwgt <= 70539': [{'fnlwgt <= 48271': ['<=50K',
#                                     {'fnlwgt <= 52849': ['<=50K',
#                                       {'occupation = Prof-specialty': ['>50K',
#                                         '<=50K']}]}]},
#                                   {'fnlwgt <= 81973': [{'workclass = Private': [{'age <= 52': [{'education_num <= 11': ['>50K',
#                                           '<=50K']},
#                                         '>50K']},
#                                       '>50K']},
#                                     {'capital_gain <= 4386': [{'fnlwgt <= 82775': ['<=50K',
#                                         {'hours_per_week <= 37': ['<=50K',
#                                           {'occupation = Machine-op-inspct': ['<=50K',
#                                             {'occupation = Craft-repair': ['<=50K',
#                                               {'workclass = State-gov': ['<=50K',
#                                                 {'fnlwgt <= 138441': [{'fnlwgt <= 95902': ['<=50K',
#                                                     {'fnlwgt <= 99682': ['>50K',
#                                                       '<=50K']}]},
#                                                   '>50K']}]}]}]}]}]},
#                                       '<=50K']}]}]},
#                                 '<=50K']}]}]},
#                           {'capital_loss <= 1485': [{'occupation = Farming-fishing': ['<=50K',
#                               {'capital_gain <= 4386': [{'occupation = Tech-support': [{'fnlwgt <= 246262': ['>50K',
#                                     {'fnlwgt <= 265266': ['<=50K', '>50K']}]},
#                                   {'occupation = Machine-op-inspct': [{'fnlwgt <= 157069': ['>50K',
#                                       {'fnlwgt <= 176050': ['<=50K',
#                                         {'race = Asian-Pac-Islander': ['>50K',
#                                           {'workclass = State-gov': ['>50K',
#                                             {'hours_per_week <= 50': [{'fnlwgt <= 201699': ['>50K',
#                                                 {'fnlwgt <= 379919': ['<=50K',
#                                                   '>50K']}]},
#                                               '<=50K']}]}]}]}]},
#                                     {'hours_per_week <= 43': [{'capital_gain <= 4064': [{'capital_gain <= 3103': [{'capital_gain <= 2407': [{'occupation = Protective-serv': [{'age <= 55': ['>50K',
#                                                 '<=50K']},
#                                               {'occupation = Prof-specialty': [{'age <= 59': [{'hours_per_week <= 40': [{'fnlwgt <= 183810': ['>50K',
#                                                       {'education_num <= 11': [{'fnlwgt <= 349405': [{'fnlwgt <= 293196': [{'native_countr = United-States': [{'age <= 46': [{'fnlwgt <= 234901': [{'workclass = Private': [{'fnlwgt <= 193524': ['<=50K',
#                                                                       {'age <= 40': ['<=50K',
#                                                                         '>50K']}]},
#                                                                     '>50K']},
#                                                                   '>50K']},
#                                                                 {'fnlwgt <= 188195': ['<=50K',
#                                                                   '>50K']}]},
#                                                               '<=50K']},
#                                                             '<=50K']},
#                                                           '>50K']},
#                                                         '>50K']}]},
#                                                     '<=50K']},
#                                                   '<=50K']},
#                                                 {'age <= 43': [{'hours_per_week <= 38': ['>50K',
#                                                     {'age <= 42': [{'fnlwgt <= 163237': [{'occupation = Craft-repair': ['>50K',
#                                                           '<=50K']},
#                                                         {'fnlwgt <= 305597': [{'fnlwgt <= 255675': [{'fnlwgt <= 241895': ['<=50K',
#                                                               '>50K']},
#                                                             '<=50K']},
#                                                           {'fnlwgt <= 312771': ['>50K',
#                                                             {'fnlwgt <= 340148': ['<=50K',
#                                                               '>50K']}]}]}]},
#                                                       {'workclass = Local-gov': ['>50K',
#                                                         '<=50K']}]}]},
#                                                   {'native_countr = United-States': [{'fnlwgt <= 365390': [{'fnlwgt <= 341695': [{'fnlwgt <= 158002': ['<=50K',
#                                                           {'fnlwgt <= 178054': [{'workclass = Private': [{'age <= 49': [{'occupation = Sales': ['>50K',
#                                                                   '<=50K']},
#                                                                 '>50K']},
#                                                               {'fnlwgt <= 168370': ['<=50K',
#                                                                 '>50K']}]},
#                                                             {'fnlwgt <= 182689': ['<=50K',
#                                                               {'workclass = Federal-gov': ['>50K',
#                                                                 {'age <= 47': ['<=50K',
#                                                                   {'age <= 50': ['>50K',
#                                                                     {'education_num <= 11': [{'occupation = Craft-repair': [{'workclass = Self-emp-inc': ['<=50K',
#                                                                           {'age <= 52': ['>50K',
#                                                                             {'fnlwgt <= 291755': [{'fnlwgt <= 257337': ['>50K',
#                                                                                 '<=50K']},
#                                                                               '>50K']}]}]},
#                                                                         '<=50K']},
#                                                                       '>50K']}]}]}]}]}]}]},
#                                                         '<=50K']},
#                                                       {'occupation = Transport-moving': ['<=50K',
#                                                         {'age <= 45': ['<=50K',
#                                                           '>50K']}]}]},
#                                                     {'age <= 51': [{'age <= 46': ['<=50K',
#                                                         '>50K']},
#                                                       '<=50K']}]}]}]}]},
#                                             '>50K']},
#                                           '<=50K']},
#                                         '>50K']},
#                                       {'fnlwgt <= 212665': [{'relationship = Husband': [{'workclass = Self-emp-inc': ['>50K',
#                                             {'fnlwgt <= 155489': ['>50K',
#                                               {'fnlwgt <= 205424': [{'fnlwgt <= 202565': [{'hours_per_week <= 66': [{'workclass = Federal-gov': ['>50K',
#                                                       {'fnlwgt <= 193815': [{'hours_per_week <= 50': [{'fnlwgt <= 180096': [{'fnlwgt <= 176814': [{'fnlwgt <= 175109': [{'age <= 52': [{'fnlwgt <= 164877': ['<=50K',
#                                                                     '>50K']},
#                                                                   '<=50K']},
#                                                                 '<=50K']},
#                                                               '>50K']},
#                                                             {'occupation = Transport-moving': ['<=50K',
#                                                               '>50K']}]},
#                                                           '<=50K']},
#                                                         '<=50K']}]},
#                                                     '>50K']},
#                                                   '>50K']},
#                                                 '<=50K']}]}]},
#                                           '>50K']},
#                                         {'age <= 37': ['<=50K',
#                                           {'occupation = Craft-repair': [{'workclass = Self-emp-inc': ['<=50K',
#                                               '>50K']},
#                                             {'hours_per_week <= 49': ['>50K',
#                                               {'fnlwgt <= 303090': ['>50K',
#                                                 {'fnlwgt <= 344743': ['>50K',
#                                                   {'age <= 40': ['<=50K',
#                                                     '>50K']}]}]}]}]}]}]}]}]}]},
#                                 '<=50K']}]},
#                             '<=50K']}]}]}]}]}]}]}]},
#             {'capital_loss <= 1977': [{'age <= 66': [{'capital_loss <= 1887': ['>50K',
#                   {'capital_loss <= 1902': [{'fnlwgt <= 225394': [{'education = Some-college': ['>50K',
#                         {'occupation = Machine-op-inspct': ['<=50K',
#                           {'occupation = Craft-repair': ['>50K',
#                             {'education = Assoc-voc': ['<=50K', '>50K']}]}]}]},
#                       '>50K']},
#                     '>50K']}]},
#                 '<=50K']},
#               {'capital_loss <= 2149': ['<=50K', '>50K']}]}]}]}]},
#       {'age <= 60': ['>50K',
#         {'capital_gain <= 6514': ['>50K',
#           {'capital_gain <= 6767': ['<=50K',
#             {'capital_gain <= 9386': ['>50K',
#               {'capital_gain <= 10566': ['<=50K', '>50K']}]}]}]}]}]},
#     {'capital_gain <= 5013': [{'capital_loss <= 1740': [{'hours_per_week <= 30': [{'relationship = Wife': ['>50K',
#             {'age <= 29': ['<=50K',
#               {'education_num <= 14': [{'occupation = Tech-support': [{'age <= 41': ['<=50K',
#                     '>50K']},
#                   {'fnlwgt <= 548510': [{'race = Asian-Pac-Islander': ['<=50K',
#                       {'age <= 67': [{'occupation = Adm-clerical': ['<=50K',
#                           {'fnlwgt <= 378239': [{'fnlwgt <= 334273': [{'hours_per_week <= 4': ['<=50K',
#                                 {'fnlwgt <= 295621': [{'workclass = Self-emp-inc': ['<=50K',
#                                     {'fnlwgt <= 239576': ['<=50K', '>50K']}]},
#                                   '<=50K']}]},
#                               '>50K']},
#                             '<=50K']}]},
#                         '<=50K']}]},
#                     '>50K']}]},
#                 {'hours_per_week <= 23': ['<=50K', '>50K']}]}]}]},
#           {'age <= 28': [{'age <= 25': ['<=50K',
#               {'sex = Male': [{'occupation = Sales': [{'hours_per_week <= 55': [{'hours_per_week <= 50': [{'capital_gain <= 0': [{'age <= 26': ['>50K',
#                           {'fnlwgt <= 175343': [{'fnlwgt <= 107812': ['>50K',
#                               '<=50K']},
#                             '>50K']}]},
#                         '<=50K']},
#                       '<=50K']},
#                     '>50K']},
#                   '<=50K']},
#                 '>50K']}]},
#             {'capital_gain <= 3103': [{'occupation = Exec-managerial': [{'capital_loss <= 0': [{'workclass = Self-emp-not-inc': [{'age <= 59': [{'native_countr = Philippines': ['<=50K',
#                         {'age <= 48': [{'education = Masters': ['>50K',
#                             {'age <= 31': ['>50K',
#                               {'fnlwgt <= 225456': [{'age <= 45': [{'age <= 40': ['<=50K',
#                                     '>50K']},
#                                   '<=50K']},
#                                 '<=50K']}]}]},
#                           '>50K']}]},
#                       '<=50K']},
#                     {'hours_per_week <= 48': [{'age <= 39': [{'fnlwgt <= 100764': [{'age <= 35': ['>50K',
#                             {'fnlwgt <= 79586': ['<=50K', '>50K']}]},
#                           {'fnlwgt <= 103408': ['<=50K',
#                             {'workclass = State-gov': ['<=50K', '>50K']}]}]},
#                         {'fnlwgt <= 355978': [{'age <= 40': ['>50K',
#                             {'age <= 70': [{'sex = Male': [{'fnlwgt <= 37353': ['>50K',
#                                   {'fnlwgt <= 46044': ['<=50K',
#                                     {'native_countr = Yugoslavia': ['<=50K',
#                                       {'native_countr = Greece': ['<=50K',
#                                         {'hours_per_week <= 32': ['<=50K',
#                                           {'hours_per_week <= 37': ['>50K',
#                                             {'race = Other': ['<=50K',
#                                               {'fnlwgt <= 352971': [{'age <= 44': [{'race = White': [{'fnlwgt <= 110355': ['>50K',
#                                                       {'fnlwgt <= 110562': ['<=50K',
#                                                         {'fnlwgt <= 320277': [{'fnlwgt <= 304906': [{'hours_per_week <= 43': ['>50K',
#                                                               {'fnlwgt <= 204662': [{'age <= 43': ['>50K',
#                                                                   '<=50K']},
#                                                                 '<=50K']}]},
#                                                             '<=50K']},
#                                                           '>50K']}]}]},
#                                                     '<=50K']},
#                                                   {'native_countr = United-States': [{'hours_per_week <= 40': [{'age <= 48': ['>50K',
#                                                         {'fnlwgt <= 231482': [{'fnlwgt <= 174102': [{'fnlwgt <= 74660': [{'fnlwgt <= 62546': ['>50K',
#                                                                 '<=50K']},
#                                                               '>50K']},
#                                                             {'education = Masters': ['>50K',
#                                                               '<=50K']}]},
#                                                           '>50K']}]},
#                                                       '>50K']},
#                                                     '>50K']}]},
#                                                 '<=50K']}]}]}]}]}]}]}]},
#                                 '>50K']},
#                               '<=50K']}]},
#                           '>50K']}]},
#                       '>50K']}]},
#                   '<=50K']},
#                 {'occupation = Prof-specialty': [{'education_num <= 14': [{'relationship = Other-relative': ['<=50K',
#                       {'capital_gain <= 1173': [{'hours_per_week <= 61': [{'native_countr = South': ['<=50K',
#                             {'age <= 36': ['>50K',
#                               {'age <= 58': [{'hours_per_week <= 56': [{'age <= 53': [{'fnlwgt <= 162238': ['>50K',
#                                       {'fnlwgt <= 164733': ['<=50K',
#                                         {'age <= 39': [{'native_countr = Canada': ['<=50K',
#                                             {'fnlwgt <= 320451': [{'fnlwgt <= 312271': [{'workclass = Self-emp-not-inc': ['<=50K',
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               '>50K']}]},
#                                           {'hours_per_week <= 50': [{'sex = Male': [{'fnlwgt <= 202692': ['>50K',
#                                                 {'fnlwgt <= 242082': ['>50K',
#                                                   {'hours_per_week <= 38': ['<=50K',
#                                                     {'age <= 48': ['>50K',
#                                                       '<=50K']}]}]}]},
#                                               '>50K']},
#                                             '<=50K']}]}]}]},
#                                     '>50K']},
#                                   '>50K']},
#                                 {'fnlwgt <= 367984': [{'fnlwgt <= 33142': ['>50K',
#                                     {'fnlwgt <= 41258': ['<=50K',
#                                       {'fnlwgt <= 53304': ['>50K',
#                                         {'race = Black': ['<=50K',
#                                           {'fnlwgt <= 195366': [{'age <= 68': [{'native_countr = United-States': [{'age <= 65': [{'age <= 63': [{'fnlwgt <= 186308': [{'fnlwgt <= 141637': [{'fnlwgt <= 113544': ['<=50K',
#                                                           {'age <= 60': ['<=50K',
#                                                             '>50K']}]},
#                                                         '<=50K']},
#                                                       '>50K']},
#                                                     '<=50K']},
#                                                   '>50K']},
#                                                 '>50K']},
#                                               '<=50K']},
#                                             '>50K']}]}]}]}]},
#                                   '>50K']}]}]}]},
#                           {'fnlwgt <= 36999': ['>50K',
#                             {'fnlwgt <= 105886': ['<=50K',
#                               {'fnlwgt <= 241174': ['>50K', '<=50K']}]}]}]},
#                         '>50K']}]},
#                     {'capital_loss <= 1485': [{'age <= 72': [{'fnlwgt <= 51264': ['>50K',
#                           {'fnlwgt <= 89011': [{'race = Asian-Pac-Islander': ['<=50K',
#                               '>50K']},
#                             {'fnlwgt <= 238912': [{'fnlwgt <= 208534': [{'hours_per_week <= 75': [{'age <= 42': [{'age <= 34': ['>50K',
#                                       {'fnlwgt <= 104280': ['>50K',
#                                         {'workclass = State-gov': ['<=50K',
#                                           {'fnlwgt <= 188576': [{'workclass = Self-emp-inc': ['>50K',
#                                               {'fnlwgt <= 188291': [{'fnlwgt <= 180686': [{'age <= 36': ['<=50K',
#                                                     {'fnlwgt <= 143368': [{'fnlwgt <= 139012': ['>50K',
#                                                         '<=50K']},
#                                                       '>50K']}]},
#                                                   '>50K']},
#                                                 '<=50K']}]},
#                                             '>50K']}]}]}]},
#                                     '>50K']},
#                                   {'education_num <= 15': ['>50K', '<=50K']}]},
#                                 '>50K']},
#                               '>50K']}]}]},
#                         '<=50K']},
#                       '<=50K']}]},
#                   {'occupation = Other-service': ['<=50K',
#                     {'workclass = Self-emp-not-inc': ['<=50K',
#                       {'hours_per_week <= 41': [{'age <= 61': [{'fnlwgt <= 293176': [{'age <= 41': [{'hours_per_week <= 35': ['>50K',
#                                 {'education_num <= 14': [{'occupation = Sales': ['>50K',
#                                     {'native_countr = Philippines': ['>50K',
#                                       {'occupation = Tech-support': ['>50K',
#                                         {'fnlwgt <= 169104': ['<=50K',
#                                           {'native_countr = United-States': [{'relationship = Own-child': ['>50K',
#                                               {'education_num <= 13': [{'workclass = Private': [{'occupation = Farming-fishing': ['<=50K',
#                                                     {'fnlwgt <= 286026': [{'fnlwgt <= 234500': ['<=50K',
#                                                         '>50K']},
#                                                       '<=50K']}]},
#                                                   '<=50K']},
#                                                 '<=50K']}]},
#                                             '<=50K']}]}]}]}]},
#                                   '<=50K']}]},
#                               {'fnlwgt <= 282744': [{'occupation = Transport-moving': ['<=50K',
#                                   {'occupation = Handlers-cleaners': ['<=50K',
#                                     {'native_countr = United-States': ['>50K',
#                                       '<=50K']}]}]},
#                                 '>50K']}]},
#                             '<=50K']},
#                           '<=50K']},
#                         {'fnlwgt <= 342448': [{'occupation = Machine-op-inspct': [{'age <= 35': ['<=50K',
#                               '>50K']},
#                             {'hours_per_week <= 52': [{'workclass = Federal-gov': ['>50K',
#                                 {'native_countr = United-States': [{'capital_loss <= 0': [{'fnlwgt <= 330144': [{'fnlwgt <= 58343': [{'fnlwgt <= 33126': [{'hours_per_week <= 44': ['<=50K',
#                                             {'fnlwgt <= 30381': ['>50K',
#                                               '<=50K']}]},
#                                           '>50K']},
#                                         {'fnlwgt <= 67725': ['<=50K',
#                                           {'occupation = Handlers-cleaners': ['<=50K',
#                                             {'age <= 35': [{'fnlwgt <= 193026': [{'fnlwgt <= 122112': [{'occupation = Sales': ['>50K',
#                                                     '<=50K']},
#                                                   '>50K']},
#                                                 '<=50K']},
#                                               '>50K']}]}]}]},
#                                       '<=50K']},
#                                     '<=50K']},
#                                   '<=50K']}]},
#                               {'education = Masters': ['>50K',
#                                 {'fnlwgt <= 113151': ['<=50K',
#                                   {'occupation = Sales': ['>50K',
#                                     '<=50K']}]}]}]}]},
#                           '>50K']}]}]}]}]}]},
#               {'capital_gain <= 4064': ['<=50K',
#                 {'capital_gain <= 4386': ['>50K', '<=50K']}]}]}]}]},
#         {'capital_loss <= 1977': ['>50K',
#           {'capital_loss <= 2163': ['<=50K', '>50K']}]}]},
#       '>50K']}]},
#   {'capital_gain <= 6849': [{'education_num <= 12': [{'age <= 28': ['<=50K',
#         {'hours_per_week <= 40': [{'capital_loss <= 2206': [{'occupation = Other-service': ['<=50K',
#               {'capital_gain <= 4650': ['<=50K',
#                 {'capital_gain <= 4787': ['>50K', '<=50K']}]}]},
#             {'capital_loss <= 2547': [{'fnlwgt <= 147372': ['>50K', '<=50K']},
#               '<=50K']}]},
#           {'capital_loss <= 2206': [{'sex = Male': [{'age <= 39': ['<=50K',
#                 {'marital_status = Never-married': [{'native_countr = England': ['>50K',
#                     {'fnlwgt <= 355728': [{'hours_per_week <= 47': ['<=50K',
#                         {'hours_per_week <= 48': [{'occupation = Adm-clerical': ['>50K',
#                             '<=50K']},
#                           '<=50K']}]},
#                       '<=50K']}]},
#                   {'education_num <= 5': ['<=50K',
#                     {'fnlwgt <= 326048': [{'occupation = Tech-support': ['>50K',
#                         {'hours_per_week <= 45': ['<=50K',
#                           {'education = Some-college': [{'age <= 43': [{'hours_per_week <= 60': ['<=50K',
#                                 '>50K']},
#                               {'workclass = Federal-gov': ['>50K',
#                                 {'hours_per_week <= 58': [{'relationship = Unmarried': [{'hours_per_week <= 50': ['<=50K',
#                                       '>50K']},
#                                     {'age <= 46': ['<=50K',
#                                       {'age <= 48': ['>50K', '<=50K']}]}]},
#                                   '<=50K']}]}]},
#                             {'relationship = Other-relative': ['>50K',
#                               '<=50K']}]}]}]},
#                       '<=50K']}]}]}]},
#               '<=50K']},
#             '>50K']}]}]},
#       {'age <= 27': ['<=50K',
#         {'hours_per_week <= 43': [{'education_num <= 14': [{'age <= 42': [{'occupation = Adm-clerical': ['<=50K',
#                 {'hours_per_week <= 30': ['<=50K',
#                   {'capital_gain <= 4650': [{'workclass = Local-gov': ['<=50K',
#                       {'age <= 34': [{'fnlwgt <= 190385': ['<=50K',
#                           {'capital_loss <= 1408': ['<=50K',
#                             {'capital_loss <= 1564': ['>50K', '<=50K']}]}]},
#                         {'marital_status = Divorced': ['<=50K',
#                           {'workclass = Private': [{'occupation = Other-service': ['<=50K',
#                               {'fnlwgt <= 65624': ['<=50K',
#                                 {'occupation = Tech-support': ['<=50K',
#                                   {'occupation = Craft-repair': ['<=50K',
#                                     {'fnlwgt <= 102976': ['>50K',
#                                       {'fnlwgt <= 408229': ['<=50K',
#                                         '>50K']}]}]}]}]}]},
#                             '<=50K']}]}]}]},
#                     {'capital_gain <= 4787': ['>50K', '<=50K']}]}]}]},
#               {'capital_loss <= 2206': [{'hours_per_week <= 20': ['<=50K',
#                   {'occupation = Craft-repair': ['<=50K',
#                     {'capital_gain <= 4650': ['<=50K',
#                       {'capital_gain <= 4934': ['>50K', '<=50K']}]}]}]},
#                 {'workclass = Private': ['>50K', '<=50K']}]}]},
#             '<=50K']},
#           {'capital_loss <= 2339': [{'occupation = Exec-managerial': [{'age <= 39': ['<=50K',
#                 {'education_num <= 14': [{'marital_status = Widowed': ['<=50K',
#                     {'workclass = Self-emp-not-inc': ['<=50K',
#                       {'fnlwgt <= 172111': [{'hours_per_week <= 55': [{'age <= 48': ['<=50K',
#                             {'hours_per_week <= 45': ['>50K', '<=50K']}]},
#                           '>50K']},
#                         {'fnlwgt <= 187830': ['>50K',
#                           {'marital_status = Separated': ['>50K',
#                             {'hours_per_week <= 60': [{'fnlwgt <= 344624': [{'hours_per_week <= 48': ['<=50K',
#                                   {'race = Amer-Indian-Eskimo': ['<=50K',
#                                     {'age <= 47': [{'age <= 46': ['>50K',
#                                         '<=50K']},
#                                       '>50K']}]}]},
#                                 '<=50K']},
#                               '<=50K']}]}]}]}]}]},
#                   '>50K']}]},
#               {'education_num <= 14': [{'sex = Male': ['<=50K',
#                   {'fnlwgt <= 130078': ['<=50K',
#                     {'fnlwgt <= 351810': [{'marital_status = Widowed': [{'hours_per_week <= 48': ['<=50K',
#                           {'fnlwgt <= 177163': ['<=50K', '>50K']}]},
#                         '<=50K']},
#                       '<=50K']}]}]},
#                 {'age <= 32': ['<=50K',
#                   {'hours_per_week <= 80': [{'workclass = Federal-gov': ['>50K',
#                       {'age <= 35': [{'fnlwgt <= 44464': ['<=50K', '>50K']},
#                         {'hours_per_week <= 50': [{'age <= 53': [{'hours_per_week <= 48': [{'marital_status = Never-married': ['<=50K',
#                                 '>50K']},
#                               {'relationship = Not-in-family': [{'occupation = Prof-specialty': ['<=50K',
#                                   '>50K']},
#                                 '>50K']}]},
#                             '<=50K']},
#                           '>50K']}]}]},
#                     '<=50K']}]}]}]},
#             '>50K']}]}]}]},
#     {'age <= 20': ['<=50K', '>50K']}]}]}

# %%
accuracy_train = calculate_accuracy(train_df,pruned_tree)
accuracy_val = calculate_accuracy(valid_df,pruned_tree)
accuracy_test = calculate_accuracy(test_df,pruned_tree)
print("Training Set Accuracy:",accuracy_train)
print("Validation Set Accuracy:",accuracy_val)
print("Test Set Accuracy:",accuracy_test)
# Out:
# Training Set Accuracy: 0.8953041982740088
# Validation Set Accuracy: 0.8844122343692421
# Test Set Accuracy: 0.8528255528255528

# %%
# metrics = {"max_depth":[],"acc_tree":[],"acc_tree_pruned":[]}

# for n in range(2,110,2):
#     tree = decision_tree_algorithm(train_df,max_depth=n)
#     tree_pruned = post_pruning(tree,train_df,valid_df)

#     metrics["max_depth"].append(n)
#     metrics["acc_tree"].append(calculate_accuracy(test_df,tree))
#     metrics["acc_tree_pruned"].append(calculate_accuracy(test_df,tree_pruned))

# df_metrics = pd.DataFrame(metrics)
# df_metrics = df_metrics.set_index("max_depth")

# %%
copy_tree = tree
copy_prune = pruned_tree

# %%
metrics = {"max_depth":[],"acc_tree_test":[],"acc_tree_pruned_test":[],"acc_tree_train":[],"acc_tree_pruned_train":[],"acc_tree_validation":[],"acc_tree_pruned_validation":[]}

# %%
p1 = pruning_result(copy_tree,train_df,valid_df)

# %%
p2 = pruning_result(p1,train_df,valid_df)

# %%
count_nodes(p2)
# Out:
# 6841

# %%
def post_pruning_gpt(tree, df_train, df_val):
    question = list(tree.keys())[0]
    yes_answer, no_answer = tree[question]

    # Base case
    if not isinstance(yes_answer, dict) and not isinstance(no_answer, dict):
        return pruning_result(tree, df_train, df_val)

    else:  # Recursive case
        df_train_yes, df_train_no = filter_df(df_train, question)
        df_val_yes, df_val_no = filter_df(df_val, question)

        if isinstance(yes_answer, dict):
            yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)

        if isinstance(no_answer, dict):
            no_answer = post_pruning(no_answer, df_train_no, df_val_no)

    pruned_tree = {question: [yes_answer, no_answer]}
    accuracy = pruning_result(pruned_tree, df_train, df_val)

    return {"Node Count": len(df_train), "Accuracy": accuracy}

# %%
test1 = post_pruning_gpt(copy_tree,train_df,valid_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 test1 = post_pruning_gpt(copy_tree,train_df,valid_df)
#
# Cell In[258], line 14, in post_pruning_gpt(tree, df_train, df_val)
#      11 df_val_yes, df_val_no = filter_df(df_val, question)
#      13 if isinstance(yes_answer, dict):
# ---> 14     yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)
#      16 if isinstance(no_answer, dict):
#      17     no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#
# Cell In[256], line 14, in post_pruning(tree, df_train, df_val)
#      11 df_val_yes, df_val_no = filter_df(df_val, question)
#      13 if isinstance(yes_answer, dict):
# ---> 14     yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)
#      16 if isinstance(no_answer, dict):
#      17     no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#
# Cell In[256], line 14, in post_pruning(tree, df_train, df_val)
#      11 df_val_yes, df_val_no = filter_df(df_val, question)
#      13 if isinstance(yes_answer, dict):
# ---> 14     yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)
#      16 if isinstance(no_answer, dict):
#      17     no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#
#     [... skipping similar frames: post_pruning at line 14 (3 times)]
#
# Cell In[256], line 17, in post_pruning(tree, df_train, df_val)
#      14         yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)
#      16     if isinstance(no_answer, dict):
# ---> 17         no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#      19 pruned_tree = {question: [yes_answer, no_answer]}
#      20 accuracy = pruning_result(pruned_tree, df_train, df_val)
#
# Cell In[256], line 17, in post_pruning(tree, df_train, df_val)
#      14         yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)
#      16     if isinstance(no_answer, dict):
# ---> 17         no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#      19 pruned_tree = {question: [yes_answer, no_answer]}
#      20 accuracy = pruning_result(pruned_tree, df_train, df_val)
#
#     [... skipping similar frames: post_pruning at line 14 (2 times)]
#
# Cell In[256], line 14, in post_pruning(tree, df_train, df_val)
#      11 df_val_yes, df_val_no = filter_df(df_val, question)
#      13 if isinstance(yes_answer, dict):
# ---> 14     yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)
#      16 if isinstance(no_answer, dict):
#      17     no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#
#     [... skipping similar frames: post_pruning at line 17 (2 times)]
#
# Cell In[256], line 17, in post_pruning(tree, df_train, df_val)
#      14         yes_answer = post_pruning(yes_answer, df_train_yes, df_val_yes)
#      16     if isinstance(no_answer, dict):
# ---> 17         no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#      19 pruned_tree = {question: [yes_answer, no_answer]}
#      20 accuracy = pruning_result(pruned_tree, df_train, df_val)
#
# Cell In[256], line 20, in post_pruning(tree, df_train, df_val)
#      17         no_answer = post_pruning(no_answer, df_train_no, df_val_no)
#      19 pruned_tree = {question: [yes_answer, no_answer]}
# ---> 20 accuracy = pruning_result(pruned_tree, df_train, df_val)
#      22 return {"Node Count": len(df_train), "Accuracy": accuracy}
#
# Cell In[229], line 4, in pruning_result(tree, df_train, df_val)
#       2 leaf = df_train.label.value_counts().index[0]
#       3 errors_leaf = sum(df_val.label != leaf) #here we can find the accuracy also :D
# ----> 4 errors_decision_node = sum(df_val.label != make_predictions(df_val,tree))
#       6 if errors_leaf <= errors_decision_node:
#       7         return leaf
#
# Cell In[227], line 4, in make_predictions(df, tree)
#       1 def make_predictions(df, tree):
#       3     if len(df) != 0:
# ----> 4         predictions = df.apply(classify_example, args=(tree,), axis=1)
#       5     else:
#       6         # "df.apply()"" with empty dataframe returns an empty dataframe,
#       7         # but "predictions" should be a series instead
#       8         predictions = pd.Series()
#
# File c:\Users\91812\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\91812\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File c:\Users\91812\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File c:\Users\91812\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# File c:\Users\91812\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:133, in Apply.__init__.<locals>.f(x)
#     132 def f(x):
# --> 133     return func(x, *args, **kwargs)
#
# Cell In[225], line 25, in classify_example(example, tree)
#      22 #recursive part
#      23 else:
#      24     remaining_tree = answer
# ---> 25     return classify_example(example,remaining_tree)
#
# Cell In[225], line 3, in classify_example(example, tree)
#       1 def classify_example(example,tree):
#       2     question = list(tree.keys())[0]
# ----> 3     feature_name , comparison_operator, value = question.split()
#       5     #Asking the question to the example
#       6     if comparison_operator == "<=":
#
# ValueError: not enough values to unpack (expected 3, got 2)
